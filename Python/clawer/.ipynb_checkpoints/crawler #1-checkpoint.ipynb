# %%
import requests

# %%
page = 1
for page in range(1,221):
    url ="http://images.asmhentai.com/009/259320/"+str(page)+".jpg"
    #print(url)
    try:
        urllib.request.urlretrieve(url, str(page)+".jpg")
        print("download"+str(page))
    except:
        continue

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get("https://asmhentai.com/gallery/259320/187/", headers=headers)
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html xmlns="https://www.w3.org/1999/xhtml/">\n<head>\n\n<title>[Hakaba] Kowashite Kudasai - Break Me [English] [Little White Butterflies + Hentaisanet &amp; Raw Crossing + desudesu] [decensored] Page 187 - AsmHentai.com</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta name="description" content="" />\n<meta name="keywords" content="hentai, manga, doujinshi, anime, hentai reader, manga reader, doujinshi reader, anime reader, cartoon">\n<meta name="robots" content="index, follow">\n<meta http-equiv="Content-Language" content="en">\n<meta name="author" content="AsmHentai" />\n<meta name="copyright" content="AsmHentai" />\n<meta name="revisit-after" content="1 day">\n<link rel="canonical" href="https://asmhentai.com/gallery/259320/187/" />\n<link rel="apple-touch-icon" href="/images/custom.png"/>\n\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/>\n<meta name="google-site-verification" content="QhlRUv6DVENd4dhC5KTtGSa-qRI4EWD4YGg1oOgOljM" />\n<link href="/favicon.ico" rel="icon" type="image/x-icon">\n\n<!-- CSS Styles -->\n<link rel="stylesheet" type="text/css" href="/css/style_light.min.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/responsive_v2.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/menu_v2.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/font-awesome.min.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/jquery-ui.min.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/sidebar.css" media="screen" />\n\n<!-- Google Fonts -->\n<link type=\'text/css\' href=\'https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,400,400italic,600\' rel=\'stylesheet\'>\n<link href=\'https://fonts.googleapis.com/css?family=Open+Sans:400,600,700\' rel=\'stylesheet\' type=\'text/css\'>\n\n<!-- Javascripts -->\n<script type="text/javascript" src="/js/jquery.min.js"></script>\n<script type="text/javascript" src="/js/jquery-ui.js"></script>\n<script type="text/javascript" src="/js/jquery.lazy.min.js"></script>\n<script src=\'https://www.google.com/recaptcha/api.js\'></script>\n\n<script type="text/javascript" src="//asmhentai.com/ft_ld.js"></script>\n\n<script type=\'text/javascript\'>\n$(document).ready(function() {\n\t\n\t$(function($) {\n\t\t$("img.lazy").Lazy({\n\t\t\ttreshold: 0,\n\t\t\tvisibleOnly: true\n\t\t});\n\t});      \n\t\n\t$(function(){\n\t\t$(".preview_thumb").slice(0, 15).show(0).css(\'display\',\'inline-block\'); // select the first 15\n\t\t\n\t\tif($(".preview_thumb").length <= 15){\n\t\t\t$("#load_more").hide();\n\t\t\t$("#load_all").hide();\n\t\t}\n\t\t\n\t\t$("#load_more").click(function(e){ // click event for load more\n\t\t\twindow.scrollBy(0,-1);\n\t\t\te.preventDefault();\n\t\t\t$(".preview_thumb:hidden").slice(0, 15).show(0).css(\'display\',\'inline-block\');// select next 15 hidden thumbs and show them\n\t\t\tif($(".preview_thumb:hidden").length == 0){ // check if any hidden divs still exist\n\t\t\t\t$("#load_more").hide();\n\t\t\t\t$("#load_all").hide();\n\t\t\t}\n\t\t});\n\t\t$("#load_all").click(function(e){ // click event for load all\n\t\t\twindow.scrollBy(0,-1);\n\t\t\te.preventDefault();\n\t\t\t$(".preview_thumb:hidden").slice(0, 3000).show(0).css(\'display\',\'inline-block\');// select next 15 hidden divs and show them\n\t\t\tif($(".preview_thumb:hidden").length == 0){ // check if any hidden divs still exist\n\t\t\t\t$("#load_more").hide();\n\t\t\t\t$("#load_all").hide();\n\t\t\t}\n\t\t});\n\t});\n\t\n\t$(".floatpc").slideToggle("slow");\n\t$(".floatmb").slideToggle("slow");\n\t\n\t$("#closefloat").click(function() {\t\n\t\t$(".floatpc").slideToggle("slow");\n\t\t$(".floatmb").slideToggle("slow");\n\t});\n\t\n \n});\n</script>\n\n<style>\n.floatpc{\n\tright: 0px;\n\tposition: fixed;\n\ttext-align: center;\n\tbottom: 0px;\n\tz-index: 9999;\n\tdisplay: none;\n}\n.floatmb{\n\tl ...

# %%
import bs4
soup = bs4.BeautifulSoup(response.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="https://www.w3.org/1999/xhtml/">
#  <head>
#   <title>
#    [Hakaba] Kowashite Kudasai - Break Me [English] [Little White Butterflies + Hentaisanet &amp; Raw Crossing + desudesu] [decensored] Page 187 - AsmHentai.com
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="" name="description">
#    <meta content="hentai, manga, doujinshi, anime, hentai reader, manga reader, doujinshi reader, anime reader, cartoon" name="keywords"/>
#    <meta content="index, follow" name="robots"/>
#    <meta content="en" http-equiv="Content-Language"/>
#    <meta content="AsmHentai" name="author">
#     <meta content="AsmHentai" name="copyright">
#      <meta content="1 day" name="revisit-after"/>
#      <link href="https://asmhentai.com/gallery/259320/187/" rel="canonical"/>
#      <link href="/images/custom.png" rel="apple-touch-icon"/>
#      <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
#       <meta content="QhlRUv6DVENd4dhC5KTtGSa-qRI4EWD4YGg1oOgOljM" name="google-site-verification">
#        <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#        <!-- CSS Styles -->
#        <link href="/css/style_light.min.css" media="screen" rel="stylesheet" type="text/css">
#         <link href="/css/responsive_v2.css" media="screen" rel="stylesheet" type="text/css"/>
#         <link href="/css/menu_v2.css" media="screen" rel="stylesheet" type="text/css"/>
#         <link href="/css/font-awesome.min.css" media="screen" rel="stylesheet" type="text/css"/>
#         <link href="/css/jquery-ui.min.css" media="screen" rel="stylesheet" type="text/css"/>
#         <link href="/css/sidebar.css" media="screen" rel="stylesheet" type="text/css"/>
#         <!-- Google Fonts -->
#         <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,400,400italic,600" rel="stylesheet" type="text/css"/>
#         <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700" rel="stylesheet" type="text/css"/>
#         <!-- Javascripts -->
#         <script src="/js/jquery.min.js" type="text/javascript">
#         </script>
#         <script src="/js/jquery-ui.js" type="text/javascript">
#         </script>
#         <script src="/js/jquery.lazy.min.js" type="text/javascript">
#         </script>
#         <script src="https://www.google.com/recaptcha/api.js">
#         </script>
#         <script src="//asmhentai.com/ft_ld.js" type="text/javascript">
#         </script>
#         <script type="text/javascript">
#          $(document).ready(function() {
#
# 	$(function($) {
# 		$("img.lazy").Lazy({
# 			treshold: 0,
# 			visibleOnly: true
# 		});
# 	});
#
# 	$(function(){
# 		$(".preview_thumb").slice(0, 15).show(0).css('display','inline-block'); // select the first 15
#
# 		if($(".preview_thumb").length <= 15){
# 			$("#load_more").hide();
# 			$("#load_all").hide();
# 		}
#
# 		$("#load_more").click(function(e){ // click event for load more
# 			window.scrollBy(0,-1);
# 			e.preventDefault();
# 			$(".preview_thumb:hidden").slice(0, 15).show(0).css('display','inline-block');// select next 15 hidden thumbs and show them
# 			if($(".preview_thumb:hidden").length == 0){ // check if any hidden divs still exist
# 				$("#load_more").hide();
# 				$("#load_all").hide();
# 			}
# 		});
# 		$("#load_all").click(function(e){ // click event for load all
# 			window.scrollBy(0,-1);
# 			e.preventDefault();
# 			$(".preview_thumb:hidden").slice(0, 3000).show(0).css('display','inline-block');// select next 15 hidden divs and show them
# 			if($(".preview_thumb:hidden").length == 0){ // check if any hidden divs still exist
# 				$("#load_more").hide();
# 				$("#load_all").hide();
# 			}
# 		});
# 	});
#
# 	$(".floatpc").slideToggle("slow");
# 	$(".floatmb").slideToggle("slow");
#
# 	$("#closefloat").click(function() {
# 		$(".floatpc").slideToggle("slow");
# 		$(".floatmb").slideToggle("slow");
# 	});
#
#
# });
#         </script>
#         <style>
#          .floatpc{
# 	right: 0px;
# 	position: fixed;
# 	text-align: center;
# 	bottom: 0px;
# 	z-index: 9999;
# 	display: none;
# }
# .floatmb{
# 	left: 50%;
# 	transform: translate(-50%, 0);
# 	position: fixed;
# 	text-align: center;
# 	bottom: 0px;
# 	z-index: 9999;
# 	display: none;
# }
# #closefloat {
# 	position: absolute;
# 	top: 0;
# 	right: 0;
# }
# .mn-container-adsby {
# 	display: none;
# }
#         </style>
#         <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css">
#          <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js">
#          </script>
#          <script>
#           window.addEventListener("load", function(){
# window.cookieconsent.initialise({
#   "palette": {
#     "popup": {
#       "background": "#252e39"
#     },
#     "button": {
#       "background": "#14a7d0"
#     }
#   },
#   "content": {
#     "href": "https://asmhentai.com/privacy/"
#   }
# })});
#          </script>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="header">
#    <div class="wrap_second">
#     <div class="left">
#      <a href="/">
#       <div class="logo">
#       </div>
#      </a>
#      <div class="nav">
#       <ul>
#        <li>
#         <a href="https://comics.asmhentai.com/" title="Hentai Porn Comics">
#          Comics
#         </a>
#        </li>
#        <li>
#         <a href="/random/">
#          Random
#         </a>
#        </li>
#        <li>
#         <a href="/parodies/">
#          Parodies
#         </a>
#        </li>
#        <li>
#         <a href="/tags/">
#          Tags
#         </a>
#        </li>
#        <li>
#         <a href="/characters/">
#          Characters
#         </a>
#        </li>
#        <li>
#         <a href="/artists/">
#          Artists
#         </a>
#        </li>
#        <li>
#         <a href="/groups/">
#          Groups
#         </a>
#        </li>
#        <div class="clear">
#        </div>
#       </ul>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="right">
#      <a href="/">
#       <div class="logomb">
#       </div>
#      </a>
#      <div class="search">
#       <form action="" id="form_search" method="POST" name="form_search">
#        <input id="searchq" name="searchq" placeholder="Search something here..." type="text" value=""/>
#        <input name="submit" type="submit" value=""/>
#        <a href="javascript:void(0);" id="dropmenu">
#         <i class="fa fa-chevron-down">
#         </i>
#        </a>
#       </form>
#       <ul class="dropmenu">
#        <li>
#         <a href="https://comics.asmhentai.com/" target="_blank" title="Porn Comics">
#          Comics
#         </a>
#        </li>
#        <li>
#         <a href="/random/">
#          Random
#         </a>
#        </li>
#        <li>
#         <a href="/parodies/">
#          Parodies
#         </a>
#        </li>
#        <li>
#         <a href="/tags/">
#          Tags
#         </a>
#        </li>
#        <li>
#         <a href="/characters/">
#          Characters
#         </a>
#        </li>
#        <li>
#         <a href="/artists/">
#          Artists
#         </a>
#        </li>
#        <li>
#         <a href="/groups/">
#          Groups
#         </a>
#        </li>
#        <li>
#         <a href="/account/">
#          Member Area
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="navicon">
#       <a href="#" id="pull">
#        <img src="/images/nav-icon.png"/>
#       </a>
#      </div>
#      <div class="nav sec">
#       <ul>
#        <li>
#         <a href="/account/">
#          <i class="fa fa-user">
#          </i>
#          Account
#         </a>
#        </li>
#        <div class="clear">
#        </div>
#       </ul>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#   </div>
#   <nav>
#    <ul>
#     <li>
#      <a href="https://comics.asmhentai.com/" target="_blank" title="Porn Comics">
#       Comics
#      </a>
#     </li>
#     <li>
#      <a href="/random/">
#       Random
#      </a>
#     </li>
#     <li>
#      <a href="/parodies/">
#       Parodies
#      </a>
#     </li>
#     <li>
#      <a href="/tags/">
#       Tags
#      </a>
#     </li>
#     <li>
#      <a href="/characters/">
#       Characters
#      </a>
#     </li>
#     <li>
#      <a href="/artists/">
#       Artists
#      </a>
#     </li>
#     <li>
#      <a href="/groups/">
#       Groups
#      </a>
#     </li>
#     <li>
#      <a href="/account/">
#       Account
#      </a>
#     </li>
#    </ul>
#    <div class="clear">
#    </div>
#   </nav>
#   <center class="atop" style="margin: 20px 0 0 0;">
#    <script type="text/javascript">
#     <!--//<![CDATA[
# 	document.write ("<scr"+"ipt type='text/javascript' src='https://go.hentaigold.net/id/4/'><\/scr"+"ipt>");
# 	//]]>-->
#    </script>
#   </center>
#   <div id="content">
#    <div class="wrap">
#     <div class="inner_content">
#      <script type="text/javascript">
#       $( document ).ready(function() {
#
# 			var Pages = parseInt(220);
#
# 			$.fn.preload = function() {
# 				this.each(function(){
# 					$('<img/>')[0].src = this;
# 				});
# 			}; $(['//images.asmhentai.com/009/259320/188.jpg','//images.asmhentai.com/009/259320/189.jpg']).preload();
#
# 			$(function(prev_nav){
#
# 			var prev_nav_c = function(prev_nav){
# 			var $self = $(this);
#
# 			$(window).scrollTop($('#img').offset().top);
#
# 			var CurrentImage = $('#img').attr('class');
# 			var CurImg = CurrentImage.split("_");
# 			var CurImg = CurImg[1];
# 			var PrevImg = parseInt(CurImg) - 1;
# 			var ChangePrev = parseInt(CurImg) - 2;
# 			var ChangeNext = parseInt(CurImg);
#
# 			if(CurImg == 1) {
# 				//console.log("begining");
# 			}
# 			else {
#
# 				$("iframe").attr("src", function ( i, val ) { return val; });
# 				$(".tracker").attr("src", function ( i, val ) { return val; });
# 				ga("send", "pageview", "/gallery/259320/"+ PrevImg +"/");
#
# 				$("#img").attr("class","image_"+ PrevImg +"");
# 				$("#img img").attr("src","//images.asmhentai.com/009/259320/"+ PrevImg +".jpg");
#
# 			}
#
# 			if(PrevImg == 0) {
# 				var PrevImg = 1;
# 			}
# 			$(".cur_selected").text("Page "+PrevImg+" of 220");
#
# 			window.history.pushState('Title', 'Title', '/gallery/259320/'+PrevImg+'/');
# 			document.title = "[Hakaba] Kowashite Kudasai - Break Me [English] [Little White Butterflies + Hentaisanet &amp; Raw Crossing + desudesu] [decensored] Page "+PrevImg+" - AsmHentai.com";
#
# 			$self.unbind("click"); //unbind
#
# 			setTimeout(function(){
# 			  $self.click(prev_nav_c);
# 			}, 500); //rebind after 500ms
#
# 			};
#
# 			$(".prev_nav").click(prev_nav_c);
#
# 		});
#
# 		$(function(next_nav){
#
# 			var next_nav_c = function(next_nav){
# 			var $self = $(this);
#
# 			$(window).scrollTop($('#img').offset().top);
#
# 			var CurrentImage = $('#img').attr('class');
# 			var CurImg = CurrentImage.split("_");
# 			var CurImg = CurImg[1];
# 			var PrevImg = parseInt(CurImg) - 1;
# 			var NextImg = parseInt(CurImg) + 1;
#
# 			var ChangePrev = parseInt(CurImg);
# 			var ChangeNext = parseInt(CurImg) + 2;
#
# 			var NextOne = parseInt(CurImg) + 1;
# 			var NextTwo = parseInt(CurImg) + 2;
#
# 			if(CurImg == Pages) {
# 				window.location.href = "//asmhentai.com/g/259320/";
# 			}
# 			else {
#
# 				$("iframe").attr("src", function ( i, val ) { return val; });
# 				$(".tracker").attr("src", function ( i, val ) { return val; });
# 				ga("send", "pageview", "/gallery/259320/"+ NextImg +"/");
#
# 				$("#img").attr("class","image_"+ NextImg +"");
# 				$("#img img").attr("src","//images.asmhentai.com/009/259320/"+ NextImg +".jpg");
#
# 				if(NextOne == Pages) {
# 					$(['//images.asmhentai.com/009/259320/'+ NextOne +'.jpg']).preload();
# 				}
# 				else {
# 					$(['//images.asmhentai.com/009/259320/'+ NextOne +'.jpg','//images.asmhentai.com/009/259320/'+ NextTwo +'.jpg']).preload();
# 				}
#
# 				$(".cur_selected").text("Page "+NextOne+" of 220");
#
# 				window.history.pushState('Title', 'Title', '/gallery/259320/'+NextOne+'/');
# 				document.title = "[Hakaba] Kowashite Kudasai - Break Me [English] [Little White Butterflies + Hentaisanet &amp; Raw Crossing + desudesu] [decensored] Page "+NextOne+" - AsmHentai.com";
#
# 			}
#
# 			$self.unbind("click"); //unbind
#
# 			setTimeout(function(){
# 			  $self.click(next_nav_c);
# 			}, 500); //rebind after 500ms
#
# 			};
#
# 			$(".next_nav").click(next_nav_c);
#
# 		});
#
# 		$(function(next_img){
#
# 			var next_img_c = function(next_img){
# 			var $self = $(this);
#
# 			$(window).scrollTop($('#img').offset().top);
#
# 			var CurrentImage = $('#img').attr('class');
# 			var CurImg = CurrentImage.split("_");
# 			var CurImg = CurImg[1];
# 			var PrevImg = parseInt(CurImg) - 1;
# 			var NextImg = parseInt(CurImg) + 1;
#
# 			var ChangePrev = parseInt(CurImg);
# 			var ChangeNext = parseInt(CurImg) + 2;
#
# 			var NextOne = parseInt(CurImg) + 1;
# 			var NextTwo = parseInt(CurImg) + 2;
#
# 			if(CurImg == Pages) {
#
# 				$.ajax({
# 					url: "/profile.php?id=259320",
# 					type: "get"
# 				});
#
# 				window.location.href = "//asmhentai.com/g/259320/";
#
# 			}
# 			else {
#
# 				$("iframe").attr("src", function ( i, val ) { return val; });
# 				$(".tracker").attr("src", function ( i, val ) { return val; });
# 				ga("send", "pageview", "/gallery/259320/"+ NextImg +"/");
#
# 				$("#img").attr("class","image_"+ NextImg +"");
# 				$("#img img").attr("src","//images.asmhentai.com/009/259320/"+ NextImg +".jpg");
#
# 				if(NextOne == Pages) {
# 					$(['//images.asmhentai.com/009/259320/'+ NextOne +'.jpg']).preload();
# 				}
# 				else {
# 					$(['//images.asmhentai.com/009/259320/'+ NextOne +'.jpg','//images.asmhentai.com/009/259320/'+ NextTwo +'.jpg']).preload();
# 				}
#
# 				$(".cur_selected").text("Page "+NextOne+" of 220");
#
# 				window.history.pushState('Title', 'Title', '/gallery/259320/'+NextOne+'/');
# 				document.title = "[Hakaba] Kowashite Kudasai - Break Me [English] [Little White Butterflies + Hentaisanet &amp; Raw Crossing + desudesu] [decensored] Page "+NextOne+" - AsmHentai.com";
#
# 			}
#
# 			$self.unbind("click"); //unbind
#
# 			setTimeout(function(){
# 			  $self.click(next_img_c);
# 			}, 500); //rebind after 500ms
#
# 			};
#
# 			$(".next_img").click(next_img_c);
#
# 		});
#
#
# 		});
#      </script>
#      <script type="text/javascript">
#       $(document).keydown(function(e){
# 				if (e.keyCode == 37) {
# 					$(location).attr("href", "/gallery/259320/186/");
# 					return false;
# 				}
# 			});
#      </script>
#      <script type="text/javascript">
#       $(document).keydown(function(e){
# 				if (e.keyCode == 39) {
# 					$(location).attr("href", "/gallery/259320/188/");
# 					return false;
# 				}
# 			});
#      </script>
#      <div class="full_gallery">
#       <div class="gallery_pagination">
#        <a class="btn gpag prev_nav" href="javascript:void(0);">
#         Prev
#        </a>
#        <label class="for_select">
#         <select class="pag_info" id="jumpto_up">
#          <option class="cur_selected" selected="" value="">
#           Page 187 of 220
#          </option>
#          <option disabled="">
#          </option>
#          <option value="/gallery/259320/1/">
#           Jump to page 1
#          </option>
#          <option value="/gallery/259320/2/">
#           Jump to page 2
#          </option>
#          <option value="/gallery/259320/3/">
#           Jump to page 3
#          </option>
#          <option value="/gallery/259320/4/">
#           Jump to page 4
#          </option>
#          <option value="/gallery/259320/5/">
#           Jump to page 5
#          </option>
#          <option value="/gallery/259320/6/">
#           Jump to page 6
#          </option>
#          <option value="/gallery/259320/7/">
#           Jump to page 7
#          </option>
#          <option value="/gallery/259320/8/">
#           Jump to page 8
#          </option>
#          <option value="/gallery/259320/9/">
#           Jump to page 9
#          </option>
#          <option value="/gallery/259320/10/">
#           Jump to page 10
#          </option>
#          <option value="/gallery/259320/11/">
#           Jump to page 11
#          </option>
#          <option value="/gallery/259320/12/">
#           Jump to page 12
#          </option>
#          <option value="/gallery/259320/13/">
#           Jump to page 13
#          </option>
#          <option value="/gallery/259320/14/">
#           Jump to page 14
#          </option>
#          <option value="/gallery/259320/15/">
#           Jump to page 15
#          </option>
#          <option value="/gallery/259320/16/">
#           Jump to page 16
#          </option>
#          <option value="/gallery/259320/17/">
#           Jump to page 17
#          </option>
#          <option value="/gallery/259320/18/">
#           Jump to page 18
#          </option>
#          <option value="/gallery/259320/19/">
#           Jump to page 19
#          </option>
#          <option value="/gallery/259320/20/">
#           Jump to page 20
#          </option>
#          <option value="/gallery/259320/21/">
#           Jump to page 21
#          </option>
#          <option value="/gallery/259320/22/">
#           Jump to page 22
#          </option>
#          <option value="/gallery/259320/23/">
#           Jump to page 23
#          </option>
#          <option value="/gallery/259320/24/">
#           Jump to page 24
#          </option>
#          <option value="/gallery/259320/25/">
#           Jump to page 25
#          </option>
#          <option value="/gallery/259320/26/">
#           Jump to page 26
#          </option>
#          <option value="/gallery/259320/27/">
#           Jump to page 27
#          </option>
#          <option value="/gallery/259320/28/">
#           Jump to page 28
#          </option>
#          <option value="/gallery/259320/29/">
#           Jump to page 29
#          </option>
#          <option value="/gallery/259320/30/">
#           Jump to page 30
#          </option>
#          <option value="/gallery/259320/31/">
#           Jump to page 31
#          </option>
#          <option value="/gallery/259320/32/">
#           Jump to page 32
#          </option>
#          <option value="/gallery/259320/33/">
#           Jump to page 33
#          </option>
#          <option value="/gallery/259320/34/">
#           Jump to page 34
#          </option>
#          <option value="/gallery/259320/35/">
#           Jump to page 35
#          </option>
#          <option value="/gallery/259320/36/">
#           Jump to page 36
#          </option>
#          <option value="/gallery/259320/37/">
#           Jump to page 37
#          </option>
#          <option value="/gallery/259320/38/">
#           Jump to page 38
#          </option>
#          <option value="/gallery/259320/39/">
#           Jump to page 39
#          </option>
#          <option value="/gallery/259320/40/">
#           Jump to page 40
#          </option>
#          <option value="/gallery/259320/41/">
#           Jump to page 41
#          </option>
#          <option value="/gallery/259320/42/">
#           Jump to page 42
#          </option>
#          <option value="/gallery/259320/43/">
#           Jump to page 43
#          </option>
#          <option value="/gallery/259320/44/">
#           Jump to page 44
#          </option>
#          <option value="/gallery/259320/45/">
#           Jump to page 45
#          </option>
#          <option value="/gallery/259320/46/">
#           Jump to page 46
#          </option>
#          <option value="/gallery/259320/47/">
#           Jump to page 47
#          </option>
#          <option value="/gallery/259320/48/">
#           Jump to page 48
#          </option>
#          <option value="/gallery/259320/49/">
#           Jump to page 49
#          </option>
#          <option value="/gallery/259320/50/">
#           Jump to page 50
#          </option>
#          <option value="/gallery/259320/51/">
#           Jump to page 51
#          </option>
#          <option value="/gallery/259320/52/">
#           Jump to page 52
#          </option>
#          <option value="/gallery/259320/53/">
#           Jump to page 53
#          </option>
#          <option value="/gallery/259320/54/">
#           Jump to page 54
#          </option>
#          <option value="/gallery/259320/55/">
#           Jump to page 55
#          </option>
#          <option value="/gallery/259320/56/">
#           Jump to page 56
#          </option>
#          <option value="/gallery/259320/57/">
#           Jump to page 57
#          </option>
#          <option value="/gallery/259320/58/">
#           Jump to page 58
#          </option>
#          <option value="/gallery/259320/59/">
#           Jump to page 59
#          </option>
#          <option value="/gallery/259320/60/">
#           Jump to page 60
#          </option>
#          <option value="/gallery/259320/61/">
#           Jump to page 61
#          </option>
#          <option value="/gallery/259320/62/">
#           Jump to page 62
#          </option>
#          <option value="/gallery/259320/63/">
#           Jump to page 63
#          </option>
#          <option value="/gallery/259320/64/">
#           Jump to page 64
#          </option>
#          <option value="/gallery/259320/65/">
#           Jump to page 65
#          </option>
#          <option value="/gallery/259320/66/">
#           Jump to page 66
#          </option>
#          <option value="/gallery/259320/67/">
#           Jump to page 67
#          </option>
#          <option value="/gallery/259320/68/">
#           Jump to page 68
#          </option>
#          <option value="/gallery/259320/69/">
#           Jump to page 69
#          </option>
#          <option value="/gallery/259320/70/">
#           Jump to page 70
#          </option>
#          <option value="/gallery/259320/71/">
#           Jump to page 71
#          </option>
#          <option value="/gallery/259320/72/">
#           Jump to page 72
#          </option>
#          <option value="/gallery/259320/73/">
#           Jump to page 73
#          </option>
#          <option value="/gallery/259320/74/">
#           Jump to page 74
#          </option>
#          <option value="/gallery/259320/75/">
#           Jump to page 75
#          </option>
#          <option value="/gallery/259320/76/">
#           Jump to page 76
#          </option>
#          <option value="/gallery/259320/77/">
#           Jump to page 77
#          </option>
#          <option value="/gallery/259320/78/">
#           Jump to page 78
#          </option>
#          <option value="/gallery/259320/79/">
#           Jump to page 79
#          </option>
#          <option value="/gallery/259320/80/">
#           Jump to page 80
#          </option>
#          <option value="/gallery/259320/81/">
#           Jump to page 81
#          </option>
#          <option value="/gallery/259320/82/">
#           Jump to page 82
#          </option>
#          <option value="/gallery/259320/83/">
#           Jump to page 83
#          </option>
#          <option value="/gallery/259320/84/">
#           Jump to page 84
#          </option>
#          <option value="/gallery/259320/85/">
#           Jump to page 85
#          </option>
#          <option value="/gallery/259320/86/">
#           Jump to page 86
#          </option>
#          <option value="/gallery/259320/87/">
#           Jump to page 87
#          </option>
#          <option value="/gallery/259320/88/">
#           Jump to page 88
#          </option>
#          <option value="/gallery/259320/89/">
#           Jump to page 89
#          </option>
#          <option value="/gallery/259320/90/">
#           Jump to page 90
#          </option>
#          <option value="/gallery/259320/91/">
#           Jump to page 91
#          </option>
#          <option value="/gallery/259320/92/">
#           Jump to page 92
#          </option>
#          <option value="/gallery/259320/93/">
#           Jump to page 93
#          </option>
#          <option value="/gallery/259320/94/">
#           Jump to page 94
#          </option>
#          <option value="/gallery/259320/95/">
#           Jump to page 95
#          </option>
#          <option value="/gallery/259320/96/">
#           Jump to page 96
#          </option>
#          <option value="/gallery/259320/97/">
#           Jump to page 97
#          </option>
#          <option value="/gallery/259320/98/">
#           Jump to page 98
#          </option>
#          <option value="/gallery/259320/99/">
#           Jump to page 99
#          </option>
#          <option value="/gallery/259320/100/">
#           Jump to page 100
#          </option>
#          <option value="/gallery/259320/101/">
#           Jump to page 101
#          </option>
#          <option value="/gallery/259320/102/">
#           Jump to page 102
#          </option>
#          <option value="/gallery/259320/103/">
#           Jump to page 103
#          </option>
#          <option value="/gallery/259320/104/">
#           Jump to page 104
#          </option>
#          <option value="/gallery/259320/105/">
#           Jump to page 105
#          </option>
#          <option value="/gallery/259320/106/">
#           Jump to page 106
#          </option>
#          <option value="/gallery/259320/107/">
#           Jump to page 107
#          </option>
#          <option value="/gallery/259320/108/">
#           Jump to page 108
#          </option>
#          <option value="/gallery/259320/109/">
#           Jump to page 109
#          </option>
#          <option value="/gallery/259320/110/">
#           Jump to page 110
#          </option>
#          <option value="/gallery/259320/111/">
#           Jump to page 111
#          </option>
#          <option value="/gallery/259320/112/">
#           Jump to page 112
#          </option>
#          <option value="/gallery/259320/113/">
#           Jump to page 113
#          </option>
#          <option value="/gallery/259320/114/">
#           Jump to page 114
#          </option>
#          <option value="/gallery/259320/115/">
#           Jump to page 115
#          </option>
#          <option value="/gallery/259320/116/">
#           Jump to page 116
#          </option>
#          <option value="/gallery/259320/117/">
#           Jump to page 117
#          </option>
#          <option value="/gallery/259320/118/">
#           Jump to page 118
#          </option>
#          <option value="/gallery/259320/119/">
#           Jump to page 119
#          </option>
#          <option value="/gallery/259320/120/">
#           Jump to page 120
#          </option>
#          <option value="/gallery/259320/121/">
#           Jump to page 121
#          </option>
#          <option value="/gallery/259320/122/">
#           Jump to page 122
#          </option>
#          <option value="/gallery/259320/123/">
#           Jump to page 123
#          </option>
#          <option value="/gallery/259320/124/">
#           Jump to page 124
#          </option>
#          <option value="/gallery/259320/125/">
#           Jump to page 125
#          </option>
#          <option value="/gallery/259320/126/">
#           Jump to page 126
#          </option>
#          <option value="/gallery/259320/127/">
#           Jump to page 127
#          </option>
#          <option value="/gallery/259320/128/">
#           Jump to page 128
#          </option>
#          <option value="/gallery/259320/129/">
#           Jump to page 129
#          </option>
#          <option value="/gallery/259320/130/">
#           Jump to page 130
#          </option>
#          <option value="/gallery/259320/131/">
#           Jump to page 131
#          </option>
#          <option value="/gallery/259320/132/">
#           Jump to page 132
#          </option>
#          <option value="/gallery/259320/133/">
#           Jump to page 133
#          </option>
#          <option value="/gallery/259320/134/">
#           Jump to page 134
#          </option>
#          <option value="/gallery/259320/135/">
#           Jump to page 135
#          </option>
#          <option value="/gallery/259320/136/">
#           Jump to page 136
#          </option>
#          <option value="/gallery/259320/137/">
#           Jump to page 137
#          </option>
#          <option value="/gallery/259320/138/">
#           Jump to page 138
#          </option>
#          <option value="/gallery/259320/139/">
#           Jump to page 139
#          </option>
#          <option value="/gallery/259320/140/">
#           Jump to page 140
#          </option>
#          <option value="/gallery/259320/141/">
#           Jump to page 141
#          </option>
#          <option value="/gallery/259320/142/">
#           Jump to page 142
#          </option>
#          <option value="/gallery/259320/143/">
#           Jump to page 143
#          </option>
#          <option value="/gallery/259320/144/">
#           Jump to page 144
#          </option>
#          <option value="/gallery/259320/145/">
#           Jump to page 145
#          </option>
#          <option value="/gallery/259320/146/">
#           Jump to page 146
#          </option>
#          <option value="/gallery/259320/147/">
#           Jump to page 147
#          </option>
#          <option value="/gallery/259320/148/">
#           Jump to page 148
#          </option>
#          <option value="/gallery/259320/149/">
#           Jump to page 149
#          </option>
#          <option value="/gallery/259320/150/">
#           Jump to page 150
#          </option>
#          <option value="/gallery/259320/151/">
#           Jump to page 151
#          </option>
#          <option value="/gallery/259320/152/">
#           Jump to page 152
#          </option>
#          <option value="/gallery/259320/153/">
#           Jump to page 153
#          </option>
#          <option value="/gallery/259320/154/">
#           Jump to page 154
#          </option>
#          <option value="/gallery/259320/155/">
#           Jump to page 155
#          </option>
#          <option value="/gallery/259320/156/">
#           Jump to page 156
#          </option>
#          <option value="/gallery/259320/157/">
#           Jump to page 157
#          </option>
#          <option value="/gallery/259320/158/">
#           Jump to page 158
#          </option>
#          <option value="/gallery/259320/159/">
#           Jump to page 159
#          </option>
#          <option value="/gallery/259320/160/">
#           Jump to page 160
#          </option>
#          <option value="/gallery/259320/161/">
#           Jump to page 161
#          </option>
#          <option value="/gallery/259320/162/">
#           Jump to page 162
#          </option>
#          <option value="/gallery/259320/163/">
#           Jump to page 163
#          </option>
#          <option value="/gallery/259320/164/">
#           Jump to page 164
#          </option>
#          <option value="/gallery/259320/165/">
#           Jump to page 165
#          </option>
#          <option value="/gallery/259320/166/">
#           Jump to page 166
#          </option>
#          <option value="/gallery/259320/167/">
#           Jump to page 167
#          </option>
#          <option value="/gallery/259320/168/">
#           Jump to page 168
#          </option>
#          <option value="/gallery/259320/169/">
#           Jump to page 169
#          </option>
#          <option value="/gallery/259320/170/">
#           Jump to page 170
#          </option>
#          <option value="/gallery/259320/171/">
#           Jump to page 171
#          </option>
#          <option value="/gallery/259320/172/">
#           Jump to page 172
#          </option>
#          <option value="/gallery/259320/173/">
#           Jump to page 173
#          </option>
#          <option value="/gallery/259320/174/">
#           Jump to page 174
#          </option>
#          <option value="/gallery/259320/175/">
#           Jump to page 175
#          </option>
#          <option value="/gallery/259320/176/">
#           Jump to page 176
#          </option>
#          <option value="/gallery/259320/177/">
#           Jump to page 177
#          </option>
#          <option value="/gallery/259320/178/">
#           Jump to page 178
#          </option>
#          <option value="/gallery/259320/179/">
#           Jump to page 179
#          </option>
#          <option value="/gallery/259320/180/">
#           Jump to page 180
#          </option>
#          <option value="/gallery/259320/181/">
#           Jump to page 181
#          </option>
#          <option value="/gallery/259320/182/">
#           Jump to page 182
#          </option>
#          <option value="/gallery/259320/183/">
#           Jump to page 183
#          </option>
#          <option value="/gallery/259320/184/">
#           Jump to page 184
#          </option>
#          <option value="/gallery/259320/185/">
#           Jump to page 185
#          </option>
#          <option value="/gallery/259320/186/">
#           Jump to page 186
#          </option>
#          <option value="/gallery/259320/187/">
#           Jump to page 187
#          </option>
#          <option value="/gallery/259320/188/">
#           Jump to page 188
#          </option>
#          <option value="/gallery/259320/189/">
#           Jump to page 189
#          </option>
#          <option value="/gallery/259320/190/">
#           Jump to page 190
#          </option>
#          <option value="/gallery/259320/191/">
#           Jump to page 191
#          </option>
#          <option value="/gallery/259320/192/">
#           Jump to page 192
#          </option>
#          <option value="/gallery/259320/193/">
#           Jump to page 193
#          </option>
#          <option value="/gallery/259320/194/">
#           Jump to page 194
#          </option>
#          <option value="/gallery/259320/195/">
#           Jump to page 195
#          </option>
#          <option value="/gallery/259320/196/">
#           Jump to page 196
#          </option>
#          <option value="/gallery/259320/197/">
#           Jump to page 197
#          </option>
#          <option value="/gallery/259320/198/">
#           Jump to page 198
#          </option>
#          <option value="/gallery/259320/199/">
#           Jump to page 199
#          </option>
#          <option value="/gallery/259320/200/">
#           Jump to page 200
#          </option>
#          <option value="/gallery/259320/201/">
#           Jump to page 201
#          </option>
#          <option value="/gallery/259320/202/">
#           Jump to page 202
#          </option>
#          <option value="/gallery/259320/203/">
#           Jump to page 203
#          </option>
#          <option value="/gallery/259320/204/">
#           Jump to page 204
#          </option>
#          <option value="/gallery/259320/205/">
#           Jump to page 205
#          </option>
#          <option value="/gallery/259320/206/">
#           Jump to page 206
#          </option>
#          <option value="/gallery/259320/207/">
#           Jump to page 207
#          </option>
#          <option value="/gallery/259320/208/">
#           Jump to page 208
#          </option>
#          <option value="/gallery/259320/209/">
#           Jump to page 209
#          </option>
#          <option value="/gallery/259320/210/">
#           Jump to page 210
#          </option>
#          <option value="/gallery/259320/211/">
#           Jump to page 211
#          </option>
#          <option value="/gallery/259320/212/">
#           Jump to page 212
#          </option>
#          <option value="/gallery/259320/213/">
#           Jump to page 213
#          </option>
#          <option value="/gallery/259320/214/">
#           Jump to page 214
#          </option>
#          <option value="/gallery/259320/215/">
#           Jump to page 215
#          </option>
#          <option value="/gallery/259320/216/">
#           Jump to page 216
#          </option>
#          <option value="/gallery/259320/217/">
#           Jump to page 217
#          </option>
#          <option value="/gallery/259320/218/">
#           Jump to page 218
#          </option>
#          <option value="/gallery/259320/219/">
#           Jump to page 219
#          </option>
#          <option value="/gallery/259320/220/">
#           Jump to page 220
#          </option>
#          <select>
#          </select>
#         </select>
#        </label>
#        <a class="btn gpag next_nav" href="javascript:void(0);">
#         Next
#        </a>
#       </div>
#       <div class="image_187" id="img">
#        <div class="full_image">
#         <a class="next_img" href="javascript:void(0);">
#          <img alt="[Hakaba] Kowashite Kudasai - Break Me [English] [Little White Butterflies + Hentaisanet &amp; Raw Crossing + desudesu] [decensored] page 187" class="lazy no_image" src="//images.asmhentai.com/009/259320/187.jpg"/>
#         </a>
#        </div>
#        <div class="gallery_pagination btm">
#         <a class="btn gpag prev_nav" href="javascript:void(0);">
#          Prev
#         </a>
#         <label class="for_select">
#          <select class="pag_info" id="jumpto_down">
#           <option class="cur_selected" selected="" value="">
#            Page 187 of 220
#           </option>
#           <option disabled="">
#           </option>
#           <option value="/gallery/259320/1/">
#            Jump to page 1
#           </option>
#           <option value="/gallery/259320/2/">
#            Jump to page 2
#           </option>
#           <option value="/gallery/259320/3/">
#            Jump to page 3
#           </option>
#           <option value="/gallery/259320/4/">
#            Jump to page 4
#           </option>
#           <option value="/gallery/259320/5/">
#            Jump to page 5
#           </option>
#           <option value="/gallery/259320/6/">
#            Jump to page 6
#           </option>
#           <option value="/gallery/259320/7/">
#            Jump to page 7
#           </option>
#           <option value="/gallery/259320/8/">
#            Jump to page 8
#           </option>
#           <option value="/gallery/259320/9/">
#            Jump to page 9
#           </option>
#           <option value="/gallery/259320/10/">
#            Jump to page 10
#           </option>
#           <option value="/gallery/259320/11/">
#            Jump to page 11
#           </option>
#           <option value="/gallery/259320/12/">
#            Jump to page 12
#           </option>
#           <option value="/gallery/259320/13/">
#            Jump to page 13
#           </option>
#           <option value="/gallery/259320/14/">
#            Jump to page 14
#           </option>
#           <option value="/gallery/259320/15/">
#            Jump to page 15
#           </option>
#           <option value="/gallery/259320/16/">
#            Jump to page 16
#           </option>
#           <option value="/gallery/259320/17/">
#            Jump to page 17
#           </option>
#           <option value="/gallery/259320/18/">
#            Jump to page 18
#           </option>
#           <option value="/gallery/259320/19/">
#            Jump to page 19
#           </option>
#           <option value="/gallery/259320/20/">
#            Jump to page 20
#           </option>
#           <option value="/gallery/259320/21/">
#            Jump to page 21
#           </option>
#           <option value="/gallery/259320/22/">
#            Jump to page 22
#           </option>
#           <option value="/gallery/259320/23/">
#            Jump to page 23
#           </option>
#           <option value="/gallery/259320/24/">
#            Jump to page 24
#           </option>
#           <option value="/gallery/259320/25/">
#            Jump to page 25
#           </option>
#           <option value="/gallery/259320/26/">
#            Jump to page 26
#           </option>
#           <option value="/gallery/259320/27/">
#            Jump to page 27
#           </option>
#           <option value="/gallery/259320/28/">
#            Jump to page 28
#           </option>
#           <option value="/gallery/259320/29/">
#            Jump to page 29
#           </option>
#           <option value="/gallery/259320/30/">
#            Jump to page 30
#           </option>
#           <option value="/gallery/259320/31/">
#            Jump to page 31
#           </option>
#           <option value="/gallery/259320/32/">
#            Jump to page 32
#           </option>
#           <option value="/gallery/259320/33/">
#            Jump to page 33
#           </option>
#           <option value="/gallery/259320/34/">
#            Jump to page 34
#           </option>
#           <option value="/gallery/259320/35/">
#            Jump to page 35
#           </option>
#           <option value="/gallery/259320/36/">
#            Jump to page 36
#           </option>
#           <option value="/gallery/259320/37/">
#            Jump to page 37
#           </option>
#           <option value="/gallery/259320/38/">
#            Jump to page 38
#           </option>
#           <option value="/gallery/259320/39/">
#            Jump to page 39
#           </option>
#           <option value="/gallery/259320/40/">
#            Jump to page 40
#           </option>
#           <option value="/gallery/259320/41/">
#            Jump to page 41
#           </option>
#           <option value="/gallery/259320/42/">
#            Jump to page 42
#           </option>
#           <option value="/gallery/259320/43/">
#            Jump to page 43
#           </option>
#           <option value="/gallery/259320/44/">
#            Jump to page 44
#           </option>
#           <option value="/gallery/259320/45/">
#            Jump to page 45
#           </option>
#           <option value="/gallery/259320/46/">
#            Jump to page 46
#           </option>
#           <option value="/gallery/259320/47/">
#            Jump to page 47
#           </option>
#           <option value="/gallery/259320/48/">
#            Jump to page 48
#           </option>
#           <option value="/gallery/259320/49/">
#            Jump to page 49
#           </option>
#           <option value="/gallery/259320/50/">
#            Jump to page 50
#           </option>
#           <option value="/gallery/259320/51/">
#            Jump to page 51
#           </option>
#           <option value="/gallery/259320/52/">
#            Jump to page 52
#           </option>
#           <option value="/gallery/259320/53/">
#            Jump to page 53
#           </option>
#           <option value="/gallery/259320/54/">
#            Jump to page 54
#           </option>
#           <option value="/gallery/259320/55/">
#            Jump to page 55
#           </option>
#           <option value="/gallery/259320/56/">
#            Jump to page 56
#           </option>
#           <option value="/gallery/259320/57/">
#            Jump to page 57
#           </option>
#           <option value="/gallery/259320/58/">
#            Jump to page 58
#           </option>
#           <option value="/gallery/259320/59/">
#            Jump to page 59
#           </option>
#           <option value="/gallery/259320/60/">
#            Jump to page 60
#           </option>
#           <option value="/gallery/259320/61/">
#            Jump to page 61
#           </option>
#           <option value="/gallery/259320/62/">
#            Jump to page 62
#           </option>
#           <option value="/gallery/259320/63/">
#            Jump to page 63
#           </option>
#           <option value="/gallery/259320/64/">
#            Jump to page 64
#           </option>
#           <option value="/gallery/259320/65/">
#            Jump to page 65
#           </option>
#           <option value="/gallery/259320/66/">
#            Jump to page 66
#           </option>
#           <option value="/gallery/259320/67/">
#            Jump to page 67
#           </option>
#           <option value="/gallery/259320/68/">
#            Jump to page 68
#           </option>
#           <option value="/gallery/259320/69/">
#            Jump to page 69
#           </option>
#           <option value="/gallery/259320/70/">
#            Jump to page 70
#           </option>
#           <option value="/gallery/259320/71/">
#            Jump to page 71
#           </option>
#           <option value="/gallery/259320/72/">
#            Jump to page 72
#           </option>
#           <option value="/gallery/259320/73/">
#            Jump to page 73
#           </option>
#           <option value="/gallery/259320/74/">
#            Jump to page 74
#           </option>
#           <option value="/gallery/259320/75/">
#            Jump to page 75
#           </option>
#           <option value="/gallery/259320/76/">
#            Jump to page 76
#           </option>
#           <option value="/gallery/259320/77/">
#            Jump to page 77
#           </option>
#           <option value="/gallery/259320/78/">
#            Jump to page 78
#           </option>
#           <option value="/gallery/259320/79/">
#            Jump to page 79
#           </option>
#           <option value="/gallery/259320/80/">
#            Jump to page 80
#           </option>
#           <option value="/gallery/259320/81/">
#            Jump to page 81
#           </option>
#           <option value="/gallery/259320/82/">
#            Jump to page 82
#           </option>
#           <option value="/gallery/259320/83/">
#            Jump to page 83
#           </option>
#           <option value="/gallery/259320/84/">
#            Jump to page 84
#           </option>
#           <option value="/gallery/259320/85/">
#            Jump to page 85
#           </option>
#           <option value="/gallery/259320/86/">
#            Jump to page 86
#           </option>
#           <option value="/gallery/259320/87/">
#            Jump to page 87
#           </option>
#           <option value="/gallery/259320/88/">
#            Jump to page 88
#           </option>
#           <option value="/gallery/259320/89/">
#            Jump to page 89
#           </option>
#           <option value="/gallery/259320/90/">
#            Jump to page 90
#           </option>
#           <option value="/gallery/259320/91/">
#            Jump to page 91
#           </option>
#           <option value="/gallery/259320/92/">
#            Jump to page 92
#           </option>
#           <option value="/gallery/259320/93/">
#            Jump to page 93
#           </option>
#           <option value="/gallery/259320/94/">
#            Jump to page 94
#           </option>
#           <option value="/gallery/259320/95/">
#            Jump to page 95
#           </option>
#           <option value="/gallery/259320/96/">
#            Jump to page 96
#           </option>
#           <option value="/gallery/259320/97/">
#            Jump to page 97
#           </option>
#           <option value="/gallery/259320/98/">
#            Jump to page 98
#           </option>
#           <option value="/gallery/259320/99/">
#            Jump to page 99
#           </option>
#           <option value="/gallery/259320/100/">
#            Jump to page 100
#           </option>
#           <option value="/gallery/259320/101/">
#            Jump to page 101
#           </option>
#           <option value="/gallery/259320/102/">
#            Jump to page 102
#           </option>
#           <option value="/gallery/259320/103/">
#            Jump to page 103
#           </option>
#           <option value="/gallery/259320/104/">
#            Jump to page 104
#           </option>
#           <option value="/gallery/259320/105/">
#            Jump to page 105
#           </option>
#           <option value="/gallery/259320/106/">
#            Jump to page 106
#           </option>
#           <option value="/gallery/259320/107/">
#            Jump to page 107
#           </option>
#           <option value="/gallery/259320/108/">
#            Jump to page 108
#           </option>
#           <option value="/gallery/259320/109/">
#            Jump to page 109
#           </option>
#           <option value="/gallery/259320/110/">
#            Jump to page 110
#           </option>
#           <option value="/gallery/259320/111/">
#            Jump to page 111
#           </option>
#           <option value="/gallery/259320/112/">
#            Jump to page 112
#           </option>
#           <option value="/gallery/259320/113/">
#            Jump to page 113
#           </option>
#           <option value="/gallery/259320/114/">
#            Jump to page 114
#           </option>
#           <option value="/gallery/259320/115/">
#            Jump to page 115
#           </option>
#           <option value="/gallery/259320/116/">
#            Jump to page 116
#           </option>
#           <option value="/gallery/259320/117/">
#            Jump to page 117
#           </option>
#           <option value="/gallery/259320/118/">
#            Jump to page 118
#           </option>
#           <option value="/gallery/259320/119/">
#            Jump to page 119
#           </option>
#           <option value="/gallery/259320/120/">
#            Jump to page 120
#           </option>
#           <option value="/gallery/259320/121/">
#            Jump to page 121
#           </option>
#           <option value="/gallery/259320/122/">
#            Jump to page 122
#           </option>
#           <option value="/gallery/259320/123/">
#            Jump to page 123
#           </option>
#           <option value="/gallery/259320/124/">
#            Jump to page 124
#           </option>
#           <option value="/gallery/259320/125/">
#            Jump to page 125
#           </option>
#           <option value="/gallery/259320/126/">
#            Jump to page 126
#           </option>
#           <option value="/gallery/259320/127/">
#            Jump to page 127
#           </option>
#           <option value="/gallery/259320/128/">
#            Jump to page 128
#           </option>
#           <option value="/gallery/259320/129/">
#            Jump to page 129
#           </option>
#           <option value="/gallery/259320/130/">
#            Jump to page 130
#           </option>
#           <option value="/gallery/259320/131/">
#            Jump to page 131
#           </option>
#           <option value="/gallery/259320/132/">
#            Jump to page 132
#           </option>
#           <option value="/gallery/259320/133/">
#            Jump to page 133
#           </option>
#           <option value="/gallery/259320/134/">
#            Jump to page 134
#           </option>
#           <option value="/gallery/259320/135/">
#            Jump to page 135
#           </option>
#           <option value="/gallery/259320/136/">
#            Jump to page 136
#           </option>
#           <option value="/gallery/259320/137/">
#            Jump to page 137
#           </option>
#           <option value="/gallery/259320/138/">
#            Jump to page 138
#           </option>
#           <option value="/gallery/259320/139/">
#            Jump to page 139
#           </option>
#           <option value="/gallery/259320/140/">
#            Jump to page 140
#           </option>
#           <option value="/gallery/259320/141/">
#            Jump to page 141
#           </option>
#           <option value="/gallery/259320/142/">
#            Jump to page 142
#           </option>
#           <option value="/gallery/259320/143/">
#            Jump to page 143
#           </option>
#           <option value="/gallery/259320/144/">
#            Jump to page 144
#           </option>
#           <option value="/gallery/259320/145/">
#            Jump to page 145
#           </option>
#           <option value="/gallery/259320/146/">
#            Jump to page 146
#           </option>
#           <option value="/gallery/259320/147/">
#            Jump to page 147
#           </option>
#           <option value="/gallery/259320/148/">
#            Jump to page 148
#           </option>
#           <option value="/gallery/259320/149/">
#            Jump to page 149
#           </option>
#           <option value="/gallery/259320/150/">
#            Jump to page 150
#           </option>
#           <option value="/gallery/259320/151/">
#            Jump to page 151
#           </option>
#           <option value="/gallery/259320/152/">
#            Jump to page 152
#           </option>
#           <option value="/gallery/259320/153/">
#            Jump to page 153
#           </option>
#           <option value="/gallery/259320/154/">
#            Jump to page 154
#           </option>
#           <option value="/gallery/259320/155/">
#            Jump to page 155
#           </option>
#           <option value="/gallery/259320/156/">
#            Jump to page 156
#           </option>
#           <option value="/gallery/259320/157/">
#            Jump to page 157
#           </option>
#           <option value="/gallery/259320/158/">
#            Jump to page 158
#           </option>
#           <option value="/gallery/259320/159/">
#            Jump to page 159
#           </option>
#           <option value="/gallery/259320/160/">
#            Jump to page 160
#           </option>
#           <option value="/gallery/259320/161/">
#            Jump to page 161
#           </option>
#           <option value="/gallery/259320/162/">
#            Jump to page 162
#           </option>
#           <option value="/gallery/259320/163/">
#            Jump to page 163
#           </option>
#           <option value="/gallery/259320/164/">
#            Jump to page 164
#           </option>
#           <option value="/gallery/259320/165/">
#            Jump to page 165
#           </option>
#           <option value="/gallery/259320/166/">
#            Jump to page 166
#           </option>
#           <option value="/gallery/259320/167/">
#            Jump to page 167
#           </option>
#           <option value="/gallery/259320/168/">
#            Jump to page 168
#           </option>
#           <option value="/gallery/259320/169/">
#            Jump to page 169
#           </option>
#           <option value="/gallery/259320/170/">
#            Jump to page 170
#           </option>
#           <option value="/gallery/259320/171/">
#            Jump to page 171
#           </option>
#           <option value="/gallery/259320/172/">
#            Jump to page 172
#           </option>
#           <option value="/gallery/259320/173/">
#            Jump to page 173
#           </option>
#           <option value="/gallery/259320/174/">
#            Jump to page 174
#           </option>
#           <option value="/gallery/259320/175/">
#            Jump to page 175
#           </option>
#           <option value="/gallery/259320/176/">
#            Jump to page 176
#           </option>
#           <option value="/gallery/259320/177/">
#            Jump to page 177
#           </option>
#           <option value="/gallery/259320/178/">
#            Jump to page 178
#           </option>
#           <option value="/gallery/259320/179/">
#            Jump to page 179
#           </option>
#           <option value="/gallery/259320/180/">
#            Jump to page 180
#           </option>
#           <option value="/gallery/259320/181/">
#            Jump to page 181
#           </option>
#           <option value="/gallery/259320/182/">
#            Jump to page 182
#           </option>
#           <option value="/gallery/259320/183/">
#            Jump to page 183
#           </option>
#           <option value="/gallery/259320/184/">
#            Jump to page 184
#           </option>
#           <option value="/gallery/259320/185/">
#            Jump to page 185
#           </option>
#           <option value="/gallery/259320/186/">
#            Jump to page 186
#           </option>
#           <option value="/gallery/259320/187/">
#            Jump to page 187
#           </option>
#           <option value="/gallery/259320/188/">
#            Jump to page 188
#           </option>
#           <option value="/gallery/259320/189/">
#            Jump to page 189
#           </option>
#           <option value="/gallery/259320/190/">
#            Jump to page 190
#           </option>
#           <option value="/gallery/259320/191/">
#            Jump to page 191
#           </option>
#           <option value="/gallery/259320/192/">
#            Jump to page 192
#           </option>
#           <option value="/gallery/259320/193/">
#            Jump to page 193
#           </option>
#           <option value="/gallery/259320/194/">
#            Jump to page 194
#           </option>
#           <option value="/gallery/259320/195/">
#            Jump to page 195
#           </option>
#           <option value="/gallery/259320/196/">
#            Jump to page 196
#           </option>
#           <option value="/gallery/259320/197/">
#            Jump to page 197
#           </option>
#           <option value="/gallery/259320/198/">
#            Jump to page 198
#           </option>
#           <option value="/gallery/259320/199/">
#            Jump to page 199
#           </option>
#           <option value="/gallery/259320/200/">
#            Jump to page 200
#           </option>
#           <option value="/gallery/259320/201/">
#            Jump to page 201
#           </option>
#           <option value="/gallery/259320/202/">
#            Jump to page 202
#           </option>
#           <option value="/gallery/259320/203/">
#            Jump to page 203
#           </option>
#           <option value="/gallery/259320/204/">
#            Jump to page 204
#           </option>
#           <option value="/gallery/259320/205/">
#            Jump to page 205
#           </option>
#           <option value="/gallery/259320/206/">
#            Jump to page 206
#           </option>
#           <option value="/gallery/259320/207/">
#            Jump to page 207
#           </option>
#           <option value="/gallery/259320/208/">
#            Jump to page 208
#           </option>
#           <option value="/gallery/259320/209/">
#            Jump to page 209
#           </option>
#           <option value="/gallery/259320/210/">
#            Jump to page 210
#           </option>
#           <option value="/gallery/259320/211/">
#            Jump to page 211
#           </option>
#           <option value="/gallery/259320/212/">
#            Jump to page 212
#           </option>
#           <option value="/gallery/259320/213/">
#            Jump to page 213
#           </option>
#           <option value="/gallery/259320/214/">
#            Jump to page 214
#           </option>
#           <option value="/gallery/259320/215/">
#            Jump to page 215
#           </option>
#           <option value="/gallery/259320/216/">
#            Jump to page 216
#           </option>
#           <option value="/gallery/259320/217/">
#            Jump to page 217
#           </option>
#           <option value="/gallery/259320/218/">
#            Jump to page 218
#           </option>
#           <option value="/gallery/259320/219/">
#            Jump to page 219
#           </option>
#           <option value="/gallery/259320/220/">
#            Jump to page 220
#           </option>
#           <select>
#           </select>
#          </select>
#         </label>
#         <a class="btn gpag next_nav" href="javascript:void(0);">
#          Next
#         </a>
#         <a class="btn gpag rt" href="/g/259320/">
#          Return to gallery
#         </a>
#        </div>
#       </div>
#       <div id="ts_ad_native_ynwre" style="margin-top:10px;">
#       </div>
#       <script src="//cdn.tsyndicate.com/sdk/v1/n.js">
#       </script>
#       <script>
#        NativeAd({
#        element_id: "ts_ad_native_ynwre",
#        spot: "e636f293ad63433198d97b410cf2d64d",
#        type: "label-over",
# 		cols: 5,
# 		rows: 1,
# 		mobileEnabled: true,
# 		title: "",
# 		titlePosition: "right",
# 		adsByPosition: "bottom-right",
# 		showLogoInfo: true,
# 		breakpoints: [
# 	          {
# 	                    "cols": 2,
# 	                    "width": 479
# 	          },
# 	          {
# 	                    "cols": 3,
# 	                    "width": 759
# 	          }
# 	],
# 	styles: {
# "image": {
# "padding-left": "15px",
# "padding-right": "15px"
# },
# "label": {
# "height": "40px",
# "background": "rgba(30,30,30,.8)"
# },
# "thumb": {
# "margin-bottom": 0
# },
# "container": {
# "padding": "6px"
# },
# "headlineLink": {
# "font-size": "14px",
# "font-weight": "normal",
# "text-align": "center",
# "color": "#d2d2d2"
# },
# "brandnameLink": {
# "font-size": "0",
# "font-weight": "bold"
# }
# }
#    });
#       </script>
#       <div class="clear">
#       </div>
#      </div>
#     </div>
#    </div>
#    <script type="text/javascript">
#     <!--//<![CDATA[
# document.write ("<scr"+"ipt type='text/javascript' src='https://go.hentaigold.net/id/10/'><\/scr"+"ipt>");
# //]]>-->
#    </script>
#    <div id="footer">
#     <div class="wrap">
#      <div class="left">
#       asmhentai.com © 2019
#      </div>
#      <div class="right">
#       <a href="/info/">
#        Info
#       </a>
#       |
#       <a href="/privacy/">
#        Privacy Policy
#       </a>
#       |
#       <a href="/contact/">
#        Contact Us
#       </a>
#       |
#       <a href="/dmca/">
#        DMCA
#       </a>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#    </div>
#    <script type="text/javascript">
#     $(function() {
# 		var pull 		= $('#pull');
# 			menu 		= $('nav ul');
#
# 		$(pull).on('click', function(e) {
# 			e.preventDefault();
# 			menu.slideToggle();
# 		});
#
# 		$(menu).hide();
#
# 		$(window).resize(function(){
# 			var w = $(window).width();
# 			if(w > 960 && menu.is(':hidden')) {
# 				menu.removeAttr('style');
# 			}
# 			if(w > 640 && w < 960) {
# 				$(menu).hide();
# 			}
# 		});
# 	});
#    </script>
#    <script src="/js/user.js" type="text/javascript">
#    </script>
#    <script src="/js/main.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     (function () {
#         var myEl = {el: null}; var event = new CustomEvent('getexoloader', {"detail": myEl}); window.document.dispatchEvent(event); var ExoLoader = myEl.el || window['ExoLoader'];
#
#         ExoLoader.serve({"script_url":"https://asmhentai.com/bk_ld.php"});
#     })();
#    </script>
#    <div class="tracker">
#     <a href="//whos.amung.us/show/zksefewvllav">
#      <img alt="web counter" src="//whos.amung.us/widget/zksefewvllav.png"/>
#     </a>
#    </div>
#    <div id="gatracker">
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-135954154-1">
#     </script>
#     <script>
#      window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-135954154-1');
#     </script>
#    </div>
#   </div>
#  </body>
# </html>

# %%
urllib.request.urlretrieve("https://images.asmhentai.com/009/259320/187.jpg", "187.jpg")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-e4fdb228c814> in <module>
# ----> 1 urllib.request.urlretrieve("https://images.asmhentai.com/009/259320/187.jpg", "187.jpg")
#
# c:\users\86116\miniconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# c:\users\86116\miniconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\86116\miniconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# c:\users\86116\miniconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# c:\users\86116\miniconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# c:\users\86116\miniconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# c:\users\86116\miniconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
soup.find_all(class_="lazy no_image")
# Out:
# [<img alt="[Hakaba] Kowashite Kudasai - Break Me [English] [Little White Butterflies + Hentaisanet &amp; Raw Crossing + desudesu] [decensored] page 187" class="lazy no_image" src="//images.asmhentai.com/009/259320/187.jpg"/>]

# %%
r = requests.get("https://images.asmhentai.com/009/259320/187.jpg",
  stream=True, headers={'User-agent': 'Mozilla/5.0'})

# %%
r
# Out:
# <Response [200]>

# %%
print(r.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x02\x00\x1c\x00\x1c\x00\x00\xff\xdb\x00C\x00\x10\x0b\x0c\x0e\x0c\n\x10\x0e\r\x0e\x12\x11\x10\x13\x18(\x1a\x18\x16\x16\x181#%\x1d(:3=<9387@H\\N@DWE78PmQW_bghg>Mqypdx\\egc\xff\xc0\x00\x0b\x08\x06@\x04L\x01\x01\x11\x00\xff\xc4\x00\x1b\x00\x01\x00\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x05\x02\x04\x06\x03\x07\xff\xc4\x00_\x10\x00\x01\x02\x03\x05\x04\x06\x06\x06\x05\t\x05\x06\x04\x01\r\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13"Q2Baq\x81\xf0\x14R\x91\xa1\xb1\xc1\x15#br\xd1\xe1\x073c\x82\xf1\x16$CS\x92\xa2\xb2\xc2\xe2%456s&DTdt\xd2U\x83\x93\xa3\xc3E\xf2\x17e\x94\xb3\xb47Vu\x84\xd4\'\xff\xda\x00\x08\x01\x01\x00\x00?\x00\xfa\x04!\x08G;\xb5\xa8\x04\xd8\xca$\nZL\x8cEF5\x8b\xcab{\xfe_\x18\xd5\xb5\x19\xf4\x8b2m\xaaT\xb8\xca\xd3\xedI\x8am\x83\x983\x1b2\xd2JhYZ\xdb\xa8\xd7_n1\xd1\xd3\xb0{<\xe1\x029WX\x1aP\xf7r\xf3\x84I\xec\xce\xb9D\x1e\x89\xcbX\xcb\x9cE;\xb5\x81\x18\x1c\x0c\x0ep\xc7\xb7]a\xa6p\x19\xf8\xc3\xd9\xe4\xc4\xe1\rt\x88\x8c\x8eq\x88\x19a\x845\xd7H\x9ab"\x00\xa0\xd6\x1a\xfb"p\x88\x19i\x90\x80\xcfL\xfeQ"\x85=\\\xa2)\xf1\x89\xba9a\x000\xad\raJi\x10F\x1a\xc0\x88S\\u\x81\xec\xa6QI\xb5\x89Svks\xc8J\x94\xa9\x19\x84?D\xe6@4>\xe2b\xeb\x05\x00p\xa1\x15\xf0\x89#\xb3\xcdb)\x1f?\xfd$I\\\x9a\x96\x9bN\x01\xc4\xdcP\xa6\xa3Z\xf8\xc7\x17\x90\x89\x18\xf6F\x04\xde\'\xbe\x07<\xe2 r\x87(\x98\x8aD\xd3\n\xe9\x10k\nf`+H\x10Ea\x13\xec\x86"\xb405\xcb\xdf\x02p\xa4}R\xd3\xad\xa9\xfa=S\x95\x05J\x94C\xa7\xbd4Q\xf8\x18\xf9^\x15\xe7\x10LMkH\x8a\xd3\x1d 5\x81\x04\xc4\xe9\x00i\xdd\x11\xa4F$\xc2\x919\x9aDw\xc4\xc4\x8e\xfc"B\xa8\xaa\xe1\nr\x89*\xc2\x83(\xc4\xc3\xb0@\x93\\b4\x89\xa68\xc2\x9d\xf4\x81\x81\xee\x89\x03\x08\x9a`#\x121\x89\x18R&\xb5\xef\x88\xa78\x94\xe2p\xa8\xed\x87\xc2:\xcd\x92\xd9\x15\xda.&r\xd1mH\x93\x18\xa1\x07\x02\xef\xfac\xe9hB[BP\x84\x84\xa5"\x80\r\x04g\x08B\x10\x84!\x18\x13Odc\xa6\xb5\xef\x84)\x81\x02\xb1\xce\xdb\xfb]%d\xef\x19d\x89\x99\xb1\x85\xc4\x9e\x14\x9f\xb4~Q\xf3{B\xd0\x9a\xb4\xe6\x9516\xe9qj\xc7\x90\x03\x90\x11\xaa;#\xdeVNbu\xed\xcc\xab.>\xe7\xaa\xdak\xfc#\xa9\xb0v1\xf5-/Zr\xc6\xe8\xa9KK]\xd4\xfe\xf51\xcfH\xeeZ\x94u\x0c!\xbd\xe0e\t\x14\xdd\xb0()\xca\xa7\x1f\x84m\xb4\xca\x1am(BBR\x9c\x80\x8fXB\x11\x11\x00\x85\n\x83\x84e\x08\xd7\x9c[\x8d\xc9>\xb6E\xe7R\xda\x8a\x075S\x08\xf3\xb3\xdaC\x12\x12\xed \xd5(h\n\xf3\xc38\xd9\xf6D\x81\xdd\x1c\'\xe9-\x1fYf\xae\x86\x9fX\x9a\xff\x00f8|9G\xdda\x08B9\xdd\xae\xa8\x16:\x80\xc4Zl\xd3\x1az\xd1{\x97\xb3\xd5\x851\xf1\xe5\xd9\x1c~\xc6)2\x96\xcd\xb7e\xe8\x87J\xd1T\xe6\x9a\x91\x97\x8ac\xb1\xd6\x9a\xd7\x97dF4\xf6\xe9\x13\x8fl1\xc7\xbf\x94\r{u\x81\xc8\xfe\x10\xd7\xc7\x94F\x9adt\x89\xd4\xfe\x10\xa7v\xba@\xf9\xc2&\x18\xf6\xc2\x10\x84G/\xc2\x18vi\xa4N\xa3\xbe e\ru\x89\xf6\xc3\x1ak\ra\x8fl@\xa9\x1e\x11?\x8cGW\xc2\'_\x1f\x94cJ\'\xc0\xc4\xfba\xed\xd6\x1c\xf3\xcb\xc6<\xdfe3\x0c8\xca\xc5R\xe2J\x0e\x1a\x11H\xaf\xd9\xd7\x1d6Ze\xdfsx\xfc\xa2\x95.\xe1\x1c\xd2h?\xbbC\xe3\x16f\xbd\xb0\xc6\xa78\xa5\xda\xdb<Z\x16\x04\xc2B\n\x9cm;\xc4a\x88\xa1\xc7\xddX\xf9%8j!\xa9\xce1\x18\x93\n\xc3\xbc@\xf3\xd2\x04CJ\xe3\x0c\xa1S]b\t4\xce\x1e\xc8D\x93\x08\x93\xdb\x9cF\xb1?\x18\x80kX\xfa\x86\xc3\xa96\x86\xc8\x19G(R\x858\xc1\xed\x07\x1f\xf3G\xcc\x9eir\xef-\x97\x05\x16\xda\x8a\x149\x10i\x18\x15W\x08\x88c\x08\x9c\x8e1\x92\x86\x04\xe5\xf6k\x18\x11\ns\x88\xee\x89\xd2\'Q\x08S\n\xf8FU\xa0\x14\x11\x8f\x84H\xba\x08\xaf\xf0\x89\x19\xf6F$C*\xc31H\x92)\xed\x88\xd78cH\x9c\xf5\x88\x1e\xe8\x94\x9av\x88cH\x03\x84G\x8cd)\xe1\x00\x055\x8c\xc2T\xaa  \x92M\xd0\x121=\x91\xde\xec\xc6\xc4\xee\x96\x89\xcba\tR\x85\n%\xf3\x03\xb5_\x84w\x00\x00\x00\x02\x822\x84!\x08B\x11\x11\x8db4\xd6\x1aS\xe5\x1a6\xa5\xad%d\xb2]\x9c}(\xa6H\x18\xa9]\xc2>\x7fnm\x9c\xed\xa4\x85\xb3(\x9fD\x978p\x9e5\x0e\xfd\x04s\x04\x93\x8e5:\xc6\xcc\x8d\x9f9i<Z\x92\x97q\xf5\x8c\xee\xe4;\xccv\xd6F\xc04\xd8\x0eZ\xce\x97\x95O\xd4\xb4h\x91\xde\xac\xcf\xba;\tYIy6\x83R\xcc6\xd2\x00\xa0\x08M#\xdcg\x19D\xc2\x10\x84#\x05V\x86\xeezV\x01@\xa8\x81\x98\x8c\xe1\x1a\xac\xfdK\xc5\x83[\xb4\xbc\xdfur\xf0\x8d\x98\x98\xe3\xff\x00H\xec\x05\xd8\xd2\xcf]\xaa\x9a\x98\x02\x ...

# %%
with open('picture_out.jpg', 'wb') as f:
  f.write(r.content)

# %%
from time import sleep
from random import random
random()
# Out:
# 0.22102771329455173

# %%
from time import sleep
from random import random
import requests
for page in range(1,221):
    url ="http://images.asmhentai.com/009/259320/"+str(page)+".jpg"
    #print(url)
    try:
        r = requests.get("https://images.asmhentai.com/009/259320/"+str(page)+".jpg",stream=True, headers={'User-agent': 'Mozilla/5.0'})
        print("download page "+str(page))
        with open(str(page)+'.jpg', 'wb') as f:
          f.write(r.content)
        sleep(random()+0.1)
    except:
        print("failed on page "+str(page))
        continue
# Out:
# download page 1
# download page 2
# download page 3
# download page 4
# download page 5
# download page 6
# download page 7
# download page 8
# download page 9
# download page 10
# download page 11
# download page 12
# download page 13
# download page 14
# download page 15
# download page 16
# download page 17
# download page 18
# download page 19
# download page 20
# download page 21
# download page 22
# download page 23
# download page 24
# download page 25
# download page 26
# download page 27
# download page 28
# download page 29
# download page 30
# download page 31
# download page 32
# download page 33
# download page 34
# download page 35
# download page 36
# download page 37
# download page 38
# download page 39
# download page 40
# download page 41
# download page 42
# download page 43
# download page 44
# download page 45
# download page 46
# download page 47
# download page 48
# download page 49
# download page 50
# download page 51
# download page 52
# download page 53
# download page 54
# download page 55
# download page 56
# download page 57
# download page 58
# download page 59
# download page 60
# download page 61
# download page 62
# download page 63
# download page 64
# download page 65
# download page 66
# download page 67
# download page 68
# download page 69
# download page 70
# download page 71
# download page 72
# download page 73
# download page 74
# download page 75
# download page 76
# download page 77
# download page 78
# download page 79
# download page 80
# download page 81
# download page 82
# download page 83
# download page 84
# download page 85
# download page 86
# download page 87
# download page 88
# download page 89
# download page 90
# download page 91
# download page 92
# download page 93
# download page 94
# download page 95
# download page 96
# download page 97
# download page 98
# download page 99
# download page 100
# download page 101
# download page 102
# download page 103
# download page 104
# download page 105
# download page 106
# download page 107
# download page 108
# download page 109
# download page 110
# download page 111
# download page 112
# download page 113
# download page 114
# download page 115
# download page 116
# download page 117
# download page 118
# download page 119
# download page 120
# download page 121
# download page 122
# download page 123
# download page 124
# download page 125
# download page 126
# download page 127
# download page 128
# download page 129
# download page 130
# download page 131
# download page 132
# download page 133
# download page 134
# download page 135
# download page 136
# download page 137
# download page 138
# download page 139
# download page 140
# download page 141
# download page 142
# download page 143
# download page 144
# download page 145
# download page 146
# download page 147
# download page 148
# download page 149
# download page 150
# download page 151
# download page 152
# download page 153
# download page 154
# download page 155
# download page 156
# download page 157
# download page 158
# download page 159
# download page 160
# download page 161
# download page 162
# download page 163
# download page 164
# download page 165
# download page 166
# download page 167
# download page 168
# download page 169
# download page 170
# download page 171
# download page 172
# download page 173
# download page 174
# download page 175
# download page 176
# download page 177
# download page 178
# download page 179
# download page 180
# download page 181
# download page 182
# download page 183
# download page 184
# download page 185
# download page 186
# download page 187
# download page 188
# download page 189
# download page 190
# download page 191
# download page 192
# download page 193
# download page 194
# download page 195
# download page 196
# download page 197
# download page 198
# download page 199
# download page 200
# download page 201
# download page 202
# download page 203
# download page 204
# download page 205
# download page 206
# download page 207
# download page 208
# download page 209
# download page 210
# download page 211
# download page 212
# download page 213
# download page 214
# download page 215
# download page 216
# download page 217
# download page 218
# download page 219
# download page 220

# %%
import os

# %%
newpath = r'C:\Users\86116\manga\[サガッとる] 濡れて蕩けて交わりて 第1-9話 [英訳] [DL版]'
if not os.path.exists(newpath):
    os.makedirs(newpath)

# %%
os.chdir(r'C:\Users\86116\manga\[サガッとる] 濡れて蕩けて交わりて 第1-9話 [英訳] [DL版]')

# %%
from time import sleep
from random import random
import requests
import os
pages = 190
mid = 268525
os.chdir(r'C:\Users\86116\manga\[サガッとる] 濡れて蕩けて交わりて 第1-9話 [英訳] [DL版]')
for page in range(1,pages+1):
    url ="https://images.asmhentai.com/009/"+str(mid)+"/"+str(page)+".jpg"
    #print(url)
    try:
        r = requests.get(url,stream=True, headers={'User-agent': 'Mozilla/5.0'})
        print("download page "+str(page))
        with open(str(page)+'.jpg', 'wb') as f:
          f.write(r.content)
        sleep(random()*0.3+0.1)
    except:
        print("failed on page "+str(page))
        continue
# Out:
# download page 1
# download page 2
# download page 3
# download page 4
# download page 5
# download page 6
# download page 7
# download page 8
# download page 9
# download page 10
# download page 11
# download page 12
# download page 13
# download page 14
# download page 15
# download page 16
# download page 17
# download page 18
# download page 19
# download page 20
# download page 21
# download page 22
# download page 23
# download page 24
# download page 25
# download page 26
# download page 27
# download page 28
# download page 29
# download page 30
# download page 31
# download page 32
# download page 33
# download page 34
# download page 35
# download page 36
# download page 37
# download page 38
# download page 39
# download page 40
# download page 41
# download page 42
# download page 43
# download page 44
# download page 45
# download page 46
# download page 47
# download page 48
# download page 49
# download page 50
# download page 51
# download page 52
# download page 53
# download page 54
# download page 55
# download page 56
# download page 57
# download page 58
# download page 59
# download page 60
# download page 61
# download page 62
# download page 63
# download page 64
# download page 65
# download page 66
# download page 67
# download page 68
# download page 69
# download page 70
# download page 71
# download page 72
# download page 73
# download page 74
# download page 75
# download page 76
# download page 77
# download page 78
# download page 79
# download page 80
# download page 81
# download page 82
# download page 83
# download page 84
# download page 85
# download page 86
# download page 87
# download page 88
# download page 89
# download page 90
# download page 91
# download page 92
# download page 93
# download page 94
# download page 95
# download page 96
# download page 97
# download page 98
# download page 99
# download page 100
# download page 101
# download page 102
# download page 103
# download page 104
# download page 105
# download page 106
# download page 107
# download page 108
# download page 109
# download page 110
# download page 111
# download page 112
# download page 113
# download page 114
# download page 115
# download page 116
# download page 117
# download page 118
# download page 119
# download page 120
# download page 121
# download page 122
# download page 123
# download page 124
# download page 125
# download page 126
# download page 127
# download page 128
# download page 129
# download page 130
# download page 131
# download page 132
# download page 133
# download page 134
# download page 135
# download page 136
# download page 137
# download page 138
# download page 139
# download page 140
# download page 141
# download page 142
# download page 143
# download page 144
# download page 145
# download page 146
# download page 147
# download page 148
# download page 149
# download page 150
# download page 151
# download page 152
# download page 153
# download page 154
# download page 155
# download page 156
# download page 157
# download page 158
# download page 159
# download page 160
# download page 161
# download page 162
# download page 163
# download page 164
# download page 165
# download page 166
# download page 167
# download page 168
# download page 169
# download page 170
# download page 171
# download page 172
# download page 173
# download page 174
# download page 175
# download page 176
# download page 177
# download page 178
# download page 179
# download page 180
# download page 181
# download page 182
# download page 183
# download page 184
# download page 185
# download page 186
# download page 187
# download page 188
# download page 189
# download page 190

# %%
pages = 190
page = 1
mid = 268525
url ="https://images.asmhentai.com/009/"+str(mid)+"/"+str(page)+".jpg"
print(url)
# Out:
# https://images.asmhentai.com/009/268525/1.jpg

# %%
import requests
url = "https://asmhentai.com/g/218071/"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=headers)
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html xmlns="https://www.w3.org/1999/xhtml/">\n<head>\n\n<title>(C89) [Dairiseki (Hakaba)] Sainan Koukou Fuuki Iin Nintei Nikubenki Nikuyoku Dorei Kotegawa Yui Ni (To LOVE-Ru) [Chinese] [\xe9\x9d\xb4\xe4\xb8\x8b\xe6\xb1\x89\xe5\x8c\x96\xe7\xbb\x84] - AsmHentai.com</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta name="description" content="Read (C89) [Dairiseki (Hakaba)] Sainan Koukou Fuuki Iin Nintei Nikubenki Nikuyoku Dorei Kotegawa Yui Ni (To LOVE-Ru) [Chinese] [\xe9\x9d\xb4\xe4\xb8\x8b\xe6\xb1\x89\xe5\x8c\x96\xe7\xbb\x84] (C89) [\xe5\xa4\xa7\xe7\x90\x86\xe7\x9f\xb3 (\xe5\xa2\x93\xe5\xa0\xb4)] \xe5\xbd\xa9\xe5\x8d\x97\xe9\xab\x98\xe6\xa0\xa1\xe9\xa2\xa8\xe7\xb4\x80\xe5\xa7\x94\xe5\x93\xa1\xe8\xaa\x8d\xe5\xae\x9a\xe8\x82\x89\xe4\xbe\xbf\xe5\x99\xa8 \xe8\x82\x89\xe6\xac\xb2\xe5\xa5\xb4\xe9\x9a\xb7\xe5\x8f\xa4\xe6\x89\x8b\xe5\xb7\x9d\xe5\x94\xaf \xe5\xbc\x90 (ToLOVE\xe3\x82\x8b -\xe3\x81\xa8\xe3\x82\x89\xe3\x81\xb6\xe3\x82\x8b-) [\xe4\xb8\xad\xe5\x9b\xbd\xe7\xbf\xbb\xe8\xa8\xb3] on asmhentai.com" />\n<meta name="keywords" content="hentai, manga, doujinshi, anime, hentai reader, manga reader, doujinshi reader, anime reader, cartoon">\n<meta name="robots" content="index, follow">\n<meta http-equiv="Content-Language" content="en">\n<meta name="author" content="AsmHentai" />\n<meta name="copyright" content="AsmHentai" />\n<meta name="revisit-after" content="1 day">\n<link rel="canonical" href="https://asmhentai.com/g/218071/" />\n<link rel="apple-touch-icon" href="/images/custom.png"/>\n\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/>\n<meta name="google-site-verification" content="QhlRUv6DVENd4dhC5KTtGSa-qRI4EWD4YGg1oOgOljM" />\n<link href="/favicon.ico" rel="icon" type="image/x-icon">\n\n<!-- CSS Styles -->\n<link rel="stylesheet" type="text/css" href="/css/style_light.min.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/responsive_v2.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/menu_v2.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/font-awesome.min.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/jquery-ui.min.css" media="screen" />\n<link rel="stylesheet" type="text/css" href="/css/sidebar.css" media="screen" />\n\n<!-- Google Fonts -->\n<link type=\'text/css\' href=\'https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,400,400italic,600\' rel=\'stylesheet\'>\n<link href=\'https://fonts.googleapis.com/css?family=Open+Sans:400,600,700\' rel=\'stylesheet\' type=\'text/css\'>\n\n<!-- Javascripts -->\n<script type="text/javascript" src="/js/jquery.min.js"></script>\n<script type="text/javascript" src="/js/jquery-ui.js"></script>\n<script type="text/javascript" src="/js/jquery.lazy.min.js"></script>\n<script src=\'https://www.google.com/recaptcha/api.js\'></script>\n\n<script type="text/javascript" src="//asmhentai.com/ft_ld.js"></script>\n\n<script type=\'text/javascript\'>\n$(document).ready(function() {\n\t\n\t$(function($) {\n\t\t$("img.lazy").Lazy({\n\t\t\ttreshold: 0,\n\t\t\tvisibleOnly: true\n\t\t});\n\t});      \n\t\n\t$(function(){\n\t\t$(".preview_thumb").slice(0, 15).show(0).css(\'display\',\'inline-block\'); // select the first 15\n\t\t\n\t\tif($(".preview_thumb").length <= 15){\n\t\t\t$("#load_more").hide();\n\t\t\t$("#load_all").hide();\n\t\t}\n\t\t\n\t\t$("#load_more").click(function(e){ // click event for load more\n\t\t\twindow.scrollBy(0,-1);\n\t\t\te.preventDefault();\n\t\t\t$(".preview_thumb:hidden").slice(0, 15).show(0).css(\'display\',\'inline-block\');// select next 15 hidden thumbs and show them\n\t\t\tif($(".preview_thumb:hidden").length == 0){ // check if any hidden divs still exist\n\t\t\t\t$("#load_more").hide();\n\t\t\t\t$("#load_all").hide();\n\t\t\t}\n\t\t});\n\t\t$("#load_all").click(function(e){ // click event for load all\n\t\t\twindow.scrollBy(0,-1);\n\t\t\te.preventDefault(); ...

# %%
import bs4
soup = bs4.BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="https://www.w3.org/1999/xhtml/">
#  <head>
#   <title>
#    (C89) [Dairiseki (Hakaba)] Sainan Koukou Fuuki Iin Nintei Nikubenki Nikuyoku Dorei Kotegawa Yui Ni (To LOVE-Ru) [Chinese] [靴下汉化组] - AsmHentai.com
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Read (C89) [Dairiseki (Hakaba)] Sainan Koukou Fuuki Iin Nintei Nikubenki Nikuyoku Dorei Kotegawa Yui Ni (To LOVE-Ru) [Chinese] [靴下汉化组] (C89) [大理石 (墓場)] 彩南高校風紀委員認定肉便器 肉欲奴隷古手川唯 弐 (ToLOVEる -とらぶる-) [中国翻訳] on asmhentai.com" name="description">
#    <meta content="hentai, manga, doujinshi, anime, hentai reader, manga reader, doujinshi reader, anime reader, cartoon" name="keywords"/>
#    <meta content="index, follow" name="robots"/>
#    <meta content="en" http-equiv="Content-Language"/>
#    <meta content="AsmHentai" name="author">
#     <meta content="AsmHentai" name="copyright">
#      <meta content="1 day" name="revisit-after"/>
#      <link href="https://asmhentai.com/g/218071/" rel="canonical"/>
#      <link href="/images/custom.png" rel="apple-touch-icon"/>
#      <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
#       <meta content="QhlRUv6DVENd4dhC5KTtGSa-qRI4EWD4YGg1oOgOljM" name="google-site-verification">
#        <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#        <!-- CSS Styles -->
#        <link href="/css/style_light.min.css" media="screen" rel="stylesheet" type="text/css">
#         <link href="/css/responsive_v2.css" media="screen" rel="stylesheet" type="text/css"/>
#         <link href="/css/menu_v2.css" media="screen" rel="stylesheet" type="text/css"/>
#         <link href="/css/font-awesome.min.css" media="screen" rel="stylesheet" type="text/css"/>
#         <link href="/css/jquery-ui.min.css" media="screen" rel="stylesheet" type="text/css"/>
#         <link href="/css/sidebar.css" media="screen" rel="stylesheet" type="text/css"/>
#         <!-- Google Fonts -->
#         <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,400,400italic,600" rel="stylesheet" type="text/css"/>
#         <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700" rel="stylesheet" type="text/css"/>
#         <!-- Javascripts -->
#         <script src="/js/jquery.min.js" type="text/javascript">
#         </script>
#         <script src="/js/jquery-ui.js" type="text/javascript">
#         </script>
#         <script src="/js/jquery.lazy.min.js" type="text/javascript">
#         </script>
#         <script src="https://www.google.com/recaptcha/api.js">
#         </script>
#         <script src="//asmhentai.com/ft_ld.js" type="text/javascript">
#         </script>
#         <script type="text/javascript">
#          $(document).ready(function() {
#
# 	$(function($) {
# 		$("img.lazy").Lazy({
# 			treshold: 0,
# 			visibleOnly: true
# 		});
# 	});
#
# 	$(function(){
# 		$(".preview_thumb").slice(0, 15).show(0).css('display','inline-block'); // select the first 15
#
# 		if($(".preview_thumb").length <= 15){
# 			$("#load_more").hide();
# 			$("#load_all").hide();
# 		}
#
# 		$("#load_more").click(function(e){ // click event for load more
# 			window.scrollBy(0,-1);
# 			e.preventDefault();
# 			$(".preview_thumb:hidden").slice(0, 15).show(0).css('display','inline-block');// select next 15 hidden thumbs and show them
# 			if($(".preview_thumb:hidden").length == 0){ // check if any hidden divs still exist
# 				$("#load_more").hide();
# 				$("#load_all").hide();
# 			}
# 		});
# 		$("#load_all").click(function(e){ // click event for load all
# 			window.scrollBy(0,-1);
# 			e.preventDefault();
# 			$(".preview_thumb:hidden").slice(0, 3000).show(0).css('display','inline-block');// select next 15 hidden divs and show them
# 			if($(".preview_thumb:hidden").length == 0){ // check if any hidden divs still exist
# 				$("#load_more").hide();
# 				$("#load_all").hide();
# 			}
# 		});
# 	});
#
# 	$(".floatpc").slideToggle("slow");
# 	$(".floatmb").slideToggle("slow");
#
# 	$("#closefloat").click(function() {
# 		$(".floatpc").slideToggle("slow");
# 		$(".floatmb").slideToggle("slow");
# 	});
#
#
# });
#         </script>
#         <style>
#          .floatpc{
# 	right: 0px;
# 	position: fixed;
# 	text-align: center;
# 	bottom: 0px;
# 	z-index: 9999;
# 	display: none;
# }
# .floatmb{
# 	left: 50%;
# 	transform: translate(-50%, 0);
# 	position: fixed;
# 	text-align: center;
# 	bottom: 0px;
# 	z-index: 9999;
# 	display: none;
# }
# #closefloat {
# 	position: absolute;
# 	top: 0;
# 	right: 0;
# }
# .mn-container-adsby {
# 	display: none;
# }
#         </style>
#         <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css">
#          <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js">
#          </script>
#          <script>
#           window.addEventListener("load", function(){
# window.cookieconsent.initialise({
#   "palette": {
#     "popup": {
#       "background": "#252e39"
#     },
#     "button": {
#       "background": "#14a7d0"
#     }
#   },
#   "content": {
#     "href": "https://asmhentai.com/privacy/"
#   }
# })});
#          </script>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="header">
#    <div class="wrap_second">
#     <div class="left">
#      <a href="/">
#       <div class="logo">
#       </div>
#      </a>
#      <div class="nav">
#       <ul>
#        <li>
#         <a href="https://comics.asmhentai.com/" title="Hentai Porn Comics">
#          Comics
#         </a>
#        </li>
#        <li>
#         <a href="/random/">
#          Random
#         </a>
#        </li>
#        <li>
#         <a href="/parodies/">
#          Parodies
#         </a>
#        </li>
#        <li>
#         <a href="/tags/">
#          Tags
#         </a>
#        </li>
#        <li>
#         <a href="/characters/">
#          Characters
#         </a>
#        </li>
#        <li>
#         <a href="/artists/">
#          Artists
#         </a>
#        </li>
#        <li>
#         <a href="/groups/">
#          Groups
#         </a>
#        </li>
#        <div class="clear">
#        </div>
#       </ul>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="right">
#      <a href="/">
#       <div class="logomb">
#       </div>
#      </a>
#      <div class="search">
#       <form action="" id="form_search" method="POST" name="form_search">
#        <input id="searchq" name="searchq" placeholder="Search something here..." type="text" value=""/>
#        <input name="submit" type="submit" value=""/>
#        <a href="javascript:void(0);" id="dropmenu">
#         <i class="fa fa-chevron-down">
#         </i>
#        </a>
#       </form>
#       <ul class="dropmenu">
#        <li>
#         <a href="https://comics.asmhentai.com/" target="_blank" title="Porn Comics">
#          Comics
#         </a>
#        </li>
#        <li>
#         <a href="/random/">
#          Random
#         </a>
#        </li>
#        <li>
#         <a href="/parodies/">
#          Parodies
#         </a>
#        </li>
#        <li>
#         <a href="/tags/">
#          Tags
#         </a>
#        </li>
#        <li>
#         <a href="/characters/">
#          Characters
#         </a>
#        </li>
#        <li>
#         <a href="/artists/">
#          Artists
#         </a>
#        </li>
#        <li>
#         <a href="/groups/">
#          Groups
#         </a>
#        </li>
#        <li>
#         <a href="/account/">
#          Member Area
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="navicon">
#       <a href="#" id="pull">
#        <img src="/images/nav-icon.png"/>
#       </a>
#      </div>
#      <div class="nav sec">
#       <ul>
#        <li>
#         <a href="/account/">
#          <i class="fa fa-user">
#          </i>
#          Account
#         </a>
#        </li>
#        <div class="clear">
#        </div>
#       </ul>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#   </div>
#   <nav>
#    <ul>
#     <li>
#      <a href="https://comics.asmhentai.com/" target="_blank" title="Porn Comics">
#       Comics
#      </a>
#     </li>
#     <li>
#      <a href="/random/">
#       Random
#      </a>
#     </li>
#     <li>
#      <a href="/parodies/">
#       Parodies
#      </a>
#     </li>
#     <li>
#      <a href="/tags/">
#       Tags
#      </a>
#     </li>
#     <li>
#      <a href="/characters/">
#       Characters
#      </a>
#     </li>
#     <li>
#      <a href="/artists/">
#       Artists
#      </a>
#     </li>
#     <li>
#      <a href="/groups/">
#       Groups
#      </a>
#     </li>
#     <li>
#      <a href="/account/">
#       Account
#      </a>
#     </li>
#    </ul>
#    <div class="clear">
#    </div>
#   </nav>
#   <center class="atop" style="margin: 20px 0 0 0;">
#    <script type="text/javascript">
#     <!--//<![CDATA[
# 	document.write ("<scr"+"ipt type='text/javascript' src='https://go.hentaigold.net/id/4/'><\/scr"+"ipt>");
# 	//]]>-->
#    </script>
#   </center>
#   <div id="content">
#    <div class="wrap">
#     <div class="inner_content">
#      <div class="book_page">
#       <div class="left">
#        <div class="cover">
#         <a href="/gallery/218071/1/">
#          <img alt="(C89) [Dairiseki (Hakaba)] Sainan Koukou Fuuki Iin Nintei Nikubenki Nikuyoku Dorei Kotegawa Yui Ni (To LOVE-Ru) [Chinese] [靴下汉化组] cover" src="//images.asmhentai.com/007/218071/cover.jpg"/>
#         </a>
#        </div>
#       </div>
#       <div class="right">
#        <div class="info">
#         <h1>
#          (C89) [Dairiseki (Hakaba)] Sainan Koukou Fuuki Iin Nintei Nikubenki Nikuyoku Dorei Kotegawa Yui Ni (To LOVE-Ru) [Chinese] [靴下汉化组]
#         </h1>
#         <h2>
#          (C89) [大理石 (墓場)] 彩南高校風紀委員認定肉便器 肉欲奴隷古手川唯 弐 (ToLOVEる -とらぶる-) [中国翻訳]
#         </h2>
#         <div class="tags">
#          <h3>
#           Parodies:
#          </h3>
#          <div class="tag_list">
#           <a href="/parodies/name/to-love-ru/">
#            <span class="badge tag">
#             to love-ru
#             <span class="gallery_count">
#              (1,435)
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="tags">
#          <h3>
#           Tags:
#          </h3>
#          <div class="tag_list">
#           <a href="/tags/name/group/">
#            <span class="badge tag">
#             group
#             <span class="gallery_count">
#              (61,338)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/anal/">
#            <span class="badge tag">
#             anal
#             <span class="gallery_count">
#              (53,817)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/sole-female/">
#            <span class="badge tag">
#             sole female
#             <span class="gallery_count">
#              (50,665)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/bondage/">
#            <span class="badge tag">
#             bondage
#             <span class="gallery_count">
#              (29,619)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/double-penetration/">
#            <span class="badge tag">
#             double penetration
#             <span class="gallery_count">
#              (20,524)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/sex-toys/">
#            <span class="badge tag">
#             sex toys
#             <span class="gallery_count">
#              (17,226)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/collar/">
#            <span class="badge tag">
#             collar
#             <span class="gallery_count">
#              (10,290)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/gag/">
#            <span class="badge tag">
#             gag
#             <span class="gallery_count">
#              (6,170)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/exhibitionism/">
#            <span class="badge tag">
#             exhibitionism
#             <span class="gallery_count">
#              (6,637)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/blindfold/">
#            <span class="badge tag">
#             blindfold
#             <span class="gallery_count">
#              (4,617)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/corset/">
#            <span class="badge tag">
#             corset
#             <span class="gallery_count">
#              (804)
#             </span>
#            </span>
#           </a>
#           <a href="/tags/name/public-use/">
#            <span class="badge tag">
#             public use
#             <span class="gallery_count">
#              (634)
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="tags">
#          <h3>
#           Characters:
#          </h3>
#          <div class="tag_list">
#           <a href="/characters/name/yui-kotegawa/">
#            <span class="badge tag">
#             yui kotegawa
#             <span class="gallery_count">
#              (302)
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="tags">
#          <h3>
#           Artists:
#          </h3>
#          <div class="tag_list">
#           <a href="/artists/name/hakaba/">
#            <span class="badge tag">
#             hakaba
#             <span class="gallery_count">
#              (189)
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="tags">
#          <h3>
#           Groups:
#          </h3>
#          <div class="tag_list">
#           <a href="/groups/name/dairiseki/">
#            <span class="badge tag">
#             dairiseki
#             <span class="gallery_count">
#              (53)
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="tags">
#          <h3>
#           Language:
#          </h3>
#          <div class="tag_list">
#           <a href="/language/translated/">
#            <span class="badge tag">
#             translated
#             <span class="gallery_count">
#              (91,579)
#             </span>
#            </span>
#           </a>
#           <a href="/language/chinese/">
#            <span class="badge tag">
#             chinese
#             <span class="gallery_count">
#              (34,497)
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="tags">
#          <h3>
#           Category:
#          </h3>
#          <div class="tag_list">
#           <a href="/category/name/doujinshi/">
#            <span class="badge tag">
#             doujinshi
#             <span class="gallery_count">
#              (200,643)
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="pages">
#          <h3>
#           Pages: 31
#          </h3>
#          <div class="clear">
#          </div>
#         </div>
#         <div class="pages">
#          <h3>
#           Added: one year ago
#          </h3>
#          <div class="clear">
#          </div>
#         </div>
#         <div class="views">
#          <div class="buttons">
#           <form action="" method="POST">
#            <input class="btn adfav" name="add_to_fav" type="submit" value=" Add to favorite (4)"/>
#           </form>
#          </div>
#          <div class="clear">
#          </div>
#         </div>
#         <div class="ads_under_details">
#         </div>
#        </div>
#       </div>
#       <div class="clear">
#       </div>
#       <!-- Start Cache 25.08.2019 04:02:48-->
#       <div class="gallery">
#        <div class="preview_thumb">
#         <a href="/gallery/218071/1/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/1t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/2/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/2t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/3/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/3t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/4/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/4t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/5/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/5t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/6/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/6t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/7/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/7t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/8/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/8t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/9/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/9t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/10/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/10t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/11/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/11t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/12/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/12t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/13/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/13t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/14/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/14t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/15/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/15t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/16/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/16t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/17/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/17t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/18/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/18t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/19/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/19t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/20/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/20t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/21/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/21t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/22/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/22t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/23/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/23t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/24/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/24t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/25/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/25t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/26/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/26t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/27/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/27t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/28/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/28t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/29/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/29t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/30/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/30t.jpg"/>
#         </a>
#        </div>
#        <div class="preview_thumb">
#         <a href="/gallery/218071/31/">
#          <img alt="" class="lazy no_image" data-src="//images.asmhentai.com/007/218071/31t.jpg"/>
#         </a>
#        </div>
#        <div class="clear">
#        </div>
#        <div style="text-align: center;">
#         <a class="btn" href="#" id="load_more">
#          <i class="fa fa-angle-down">
#          </i>
#          View More
#         </a>
#         <a class="btn" href="#" id="load_all">
#          <i class="fa fa-angle-double-down">
#          </i>
#          View All
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- End Cache -->
#      <div class="book_page">
#       <div class="gallery">
#        <div id="ts_ad_native_ynwre" style="margin-top:10px;">
#        </div>
#        <script src="//cdn.tsyndicate.com/sdk/v1/n.js">
#        </script>
#        <script>
#         NativeAd({
#        element_id: "ts_ad_native_ynwre",
#        spot: "e636f293ad63433198d97b410cf2d64d",
#        type: "label-over",
# 		cols: 5,
# 		rows: 1,
# 		mobileEnabled: true,
# 		title: "",
# 		titlePosition: "right",
# 		adsByPosition: "bottom-right",
# 		showLogoInfo: true,
# 		breakpoints: [
# 	          {
# 	                    "cols": 2,
# 	                    "width": 479
# 	          },
# 	          {
# 	                    "cols": 3,
# 	                    "width": 759
# 	          }
# 	],
# 	styles: {
# "image": {
# "padding-left": "15px",
# "padding-right": "15px"
# },
# "label": {
# "height": "40px",
# "background": "rgba(30,30,30,.8)"
# },
# "thumb": {
# "margin-bottom": 0
# },
# "container": {
# "padding": "6px"
# },
# "headlineLink": {
# "font-size": "14px",
# "font-weight": "normal",
# "text-align": "center",
# "color": "#d2d2d2"
# },
# "brandnameLink": {
# "font-size": "0",
# "font-weight": "bold"
# }
# }
#    });
#        </script>
#       </div>
#      </div>
#      <div class="comments">
#       <ul>
#        <div class="comments_count">
#         0 comments.
#        </div>
#        <div class="alert alert-warning">
#         <i class="fa fa-info-circle">
#         </i>
#         Info: You need to be logged in for posting a comment.
#         <a href="/account/">
#          Login
#         </a>
#         or
#         <a href="/account/">
#          Register
#         </a>
#         .
#        </div>
#       </ul>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    <!--//<![CDATA[
# document.write ("<scr"+"ipt type='text/javascript' src='https://go.hentaigold.net/id/10/'><\/scr"+"ipt>");
# //]]>-->
#   </script>
#   <div id="footer">
#    <div class="wrap">
#     <div class="left">
#      asmhentai.com © 2019
#     </div>
#     <div class="right">
#      <a href="/info/">
#       Info
#      </a>
#      |
#      <a href="/privacy/">
#       Privacy Policy
#      </a>
#      |
#      <a href="/contact/">
#       Contact Us
#      </a>
#      |
#      <a href="/dmca/">
#       DMCA
#      </a>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    $(function() {
# 		var pull 		= $('#pull');
# 			menu 		= $('nav ul');
#
# 		$(pull).on('click', function(e) {
# 			e.preventDefault();
# 			menu.slideToggle();
# 		});
#
# 		$(menu).hide();
#
# 		$(window).resize(function(){
# 			var w = $(window).width();
# 			if(w > 960 && menu.is(':hidden')) {
# 				menu.removeAttr('style');
# 			}
# 			if(w > 640 && w < 960) {
# 				$(menu).hide();
# 			}
# 		});
# 	});
#   </script>
#   <script src="/js/user.js" type="text/javascript">
#   </script>
#   <script src="/js/main.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    (function () {
#         var myEl = {el: null}; var event = new CustomEvent('getexoloader', {"detail": myEl}); window.document.dispatchEvent(event); var ExoLoader = myEl.el || window['ExoLoader'];
#
#         ExoLoader.serve({"script_url":"https://asmhentai.com/bk_ld.php"});
#     })();
#   </script>
#   <div class="tracker">
#    <a href="//whos.amung.us/show/zksefewvllav">
#     <img alt="web counter" src="//whos.amung.us/widget/zksefewvllav.png"/>
#    </a>
#   </div>
#   <div id="gatracker">
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-135954154-1">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-135954154-1');
#    </script>
#   </div>
#  </body>
# </html>

# %%
soup.find_all('h2')
# Out:
# [<h2>(C89) [大理石 (墓場)] 彩南高校風紀委員認定肉便器 肉欲奴隷古手川唯 弐 (ToLOVEる -とらぶる-) [中国翻訳]</h2>]

# %%
title = soup.h2.string
print(title)
# Out:
# (C89) [大理石 (墓場)] 彩南高校風紀委員認定肉便器 肉欲奴隷古手川唯 弐 (ToLOVEる -とらぶる-) [中国翻訳]

# %%
pages = int(soup.find("div", {"class": "pages"}).find('h3').string[7:])
# Out:
# '31'

# %%
mid = url[24:-1]
url
# Out:
# 'https://asmhentai.com/g/218071/'

# %%
url = "http:"+soup.find("div", {"class": "cover"}).find('img')['src'][:-9]
print(url)
# Out:
# http://images.asmhentai.com/007/218071/

# %%
from time import sleep
from random import random
import requests
import os
import bs4
src = "https://asmhentai.com/g/268981/"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(src, headers=headers)
soup = bs4.BeautifulSoup(response.content, 'html.parser')
title = soup.h2.string
root = "http:"+soup.find("div", {"class": "cover"}).find('img')['src'][:-9]
pages = int(soup.find("div", {"class": "pages"}).find('h3').string[7:])
print(title,root,pages)
newpath = 'C:\\Users\\86116\\manga\\'+title
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
for page in range(1,pages+1):
    url = root+str(page)+".jpg"
    #print(url)
    try:
        r = requests.get(url,stream=True, headers={'User-agent': 'Mozilla/5.0'})
        print("download page "+str(page))
        with open(str(page)+'.jpg', 'wb') as f:
          f.write(r.content)
        sleep(random()*0.1+0.1)
    except:
        print("failed on page "+str(page))
        continue
# Out:
# [井上よしひさ] くノ一淫縛大戦 http://images.asmhentai.com/009/268981/ 232
# download page 1
# download page 2
# download page 3
# download page 4
# download page 5
# download page 6
# download page 7
# download page 8
# download page 9
# download page 10
# download page 11
# download page 12
# download page 13
# download page 14
# download page 15
# download page 16
# download page 17
# download page 18
# download page 19
# download page 20
# download page 21
# download page 22
# download page 23
# download page 24
# download page 25
# download page 26
# download page 27
# download page 28
# download page 29
# download page 30
# download page 31
# download page 32
# download page 33
# download page 34
# download page 35
# download page 36
# download page 37
# download page 38
# download page 39
# download page 40
# download page 41
# download page 42
# download page 43
# download page 44
# download page 45
# download page 46
# download page 47
# download page 48
# download page 49
# download page 50
# download page 51
# download page 52
# download page 53
# download page 54
# download page 55
# download page 56
# download page 57
# download page 58
# download page 59
# download page 60
# download page 61
# download page 62
# download page 63
# download page 64
# download page 65
# download page 66
# download page 67
# download page 68
# download page 69
# download page 70
# download page 71
# download page 72
# download page 73
# download page 74
# download page 75
# download page 76
# download page 77
# download page 78
# download page 79
# download page 80
# download page 81
# download page 82
# download page 83
# download page 84
# download page 85
# download page 86
# download page 87
# download page 88
# download page 89
# download page 90
# download page 91
# download page 92
# download page 93
# download page 94
# download page 95
# download page 96
# download page 97
# download page 98
# download page 99
# download page 100
# download page 101
# download page 102
# download page 103
# download page 104
# download page 105
# download page 106
# download page 107
# download page 108
# download page 109
# download page 110
# download page 111
# download page 112
# download page 113
# download page 114
# download page 115
# download page 116
# download page 117
# download page 118
# download page 119
# download page 120
# download page 121
# download page 122
# download page 123
# download page 124
# download page 125
# download page 126
# download page 127
# download page 128
# download page 129
# download page 130
# download page 131
# download page 132
# download page 133
# download page 134
# download page 135
# download page 136
# download page 137
# download page 138
# download page 139
# download page 140
# download page 141
# download page 142
# download page 143
# download page 144
# download page 145
# download page 146
# download page 147
# download page 148
# download page 149

# %%
mid
# Out:
# '.com/009/218071/31.jp'

# %%
url
# Out:
# 'https://images.asmhentai.com/009/218071/31.jpg'

# %%
title
# Out:
# '(C89) [大理石 (墓場)] 彩南高校風紀委員認定肉便器 肉欲奴隷古手川唯 弐 (ToLOVEる -とらぶる-) [中国翻訳]'

# %%
# Out:
# (C89) [大理石 (墓場)] 彩南高校風紀委員認定肉便器 肉欲奴隷古手川唯 弐 (ToLOVEる -とらぶる-) [中国翻訳] http://images.asmhentai.com/007/218071/ 31
